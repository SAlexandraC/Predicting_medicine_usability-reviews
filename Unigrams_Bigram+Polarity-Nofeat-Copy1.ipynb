# %% [markdown]
# # Import libraries

# %%
# !pip install --upgrade pip setuptools
# !pip install wordcloud
# !pip install lightgbm
# !pip install nltk
# !pip install imbalanced-learn
# !pip install --upgrade scikit-learn
# !pip install --upgrade imbalanced-learn
# !pip install -U Textblob
# !python -m textblob.download_corpora
# !pip install unidecode
# !pip install lightgbm==2.2.3
# !pip install contractions
# !pip install scikit-optimize
# !pip install scipy
# Out:
# Requirement already satisfied: pip in /opt/anaconda3/lib/python3.11/site-packages (24.0)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.11/site-packages (69.5.1)
# Requirement already satisfied: wordcloud in /opt/anaconda3/lib/python3.11/site-packages (1.9.3)
# Requirement already satisfied: numpy>=1.6.1 in /opt/anaconda3/lib/python3.11/site-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in /opt/anaconda3/lib/python3.11/site-packages (from wordcloud) (10.2.0)
# Requirement already satisfied: matplotlib in /opt/anaconda3/lib/python3.11/site-packages (from wordcloud) (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Requirement already satisfied: nltk in /opt/anaconda3/lib/python3.11/site-packages (3.8.1)
# Requirement already satisfied: click in /opt/anaconda3/lib/python3.11/site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /opt/anaconda3/lib/python3.11/site-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /opt/anaconda3/lib/python3.11/site-packages (from nltk) (2023.10.3)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.11/site-packages (from nltk) (4.65.0)
# Requirement already satisfied: imbalanced-learn in /opt/anaconda3/lib/python3.11/site-packages (0.12.2)
# Requirement already satisfied: numpy>=1.17.3 in /opt/anaconda3/lib/python3.11/site-packages (from imbalanced-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.5.0 in /opt/anaconda3/lib/python3.11/site-packages (from imbalanced-learn) (1.11.4)
# Requirement already satisfied: scikit-learn>=1.0.2 in /opt/anaconda3/lib/python3.11/site-packages (from imbalanced-learn) (1.4.2)
# Requirement already satisfied: joblib>=1.1.1 in /opt/anaconda3/lib/python3.11/site-packages (from imbalanced-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from imbalanced-learn) (2.2.0)
# Requirement already satisfied: scikit-learn in /opt/anaconda3/lib/python3.11/site-packages (1.4.2)
# Requirement already satisfied: numpy>=1.19.5 in /opt/anaconda3/lib/python3.11/site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /opt/anaconda3/lib/python3.11/site-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: imbalanced-learn in /opt/anaconda3/lib/python3.11/site-packages (0.12.2)
# Requirement already satisfied: numpy>=1.17.3 in /opt/anaconda3/lib/python3.11/site-packages (from imbalanced-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.5.0 in /opt/anaconda3/lib/python3.11/site-packages (from imbalanced-learn) (1.11.4)
# Requirement already satisfied: scikit-learn>=1.0.2 in /opt/anaconda3/lib/python3.11/site-packages (from imbalanced-learn) (1.4.2)
# Requirement already satisfied: joblib>=1.1.1 in /opt/anaconda3/lib/python3.11/site-packages (from imbalanced-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from imbalanced-learn) (2.2.0)
# Requirement already satisfied: Textblob in /opt/anaconda3/lib/python3.11/site-packages (0.18.0.post0)
# Requirement already satisfied: nltk>=3.8 in /opt/anaconda3/lib/python3.11/site-packages (from Textblob) (3.8.1)
# Requirement already satisfied: click in /opt/anaconda3/lib/python3.11/site-packages (from nltk>=3.8->Textblob) (8.1.7)
# Requirement already satisfied: joblib in /opt/anaconda3/lib/python3.11/site-packages (from nltk>=3.8->Textblob) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /opt/anaconda3/lib/python3.11/site-packages (from nltk>=3.8->Textblob) (2023.10.3)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.11/site-packages (from nltk>=3.8->Textblob) (4.65.0)
# [nltk_data] Downloading package brown to
# [nltk_data]     /Users/sebastianhaecker/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/sebastianhaecker/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/sebastianhaecker/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/sebastianhaecker/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package conll2000 to
# [nltk_data]     /Users/sebastianhaecker/nltk_data...
# [nltk_data]   Package conll2000 is already up-to-date!
# [nltk_data] Downloading package movie_reviews to
# [nltk_data]     /Users/sebastianhaecker/nltk_data...
# [nltk_data]   Package movie_reviews is already up-to-date!
# Finished.
# Requirement already satisfied: unidecode in /opt/anaconda3/lib/python3.11/site-packages (1.2.0)
# Requirement already satisfied: contractions in /opt/anaconda3/lib/python3.11/site-packages (0.1.73)
# Requirement already satisfied: textsearch>=0.0.21 in /opt/anaconda3/lib/python3.11/site-packages (from contractions) (0.0.24)
# Requirement already satisfied: anyascii in /opt/anaconda3/lib/python3.11/site-packages (from textsearch>=0.0.21->contractions) (0.3.2)
# Requirement already satisfied: pyahocorasick in /opt/anaconda3/lib/python3.11/site-packages (from textsearch>=0.0.21->contractions) (2.1.0)
# Requirement already satisfied: scikit-optimize in /opt/anaconda3/lib/python3.11/site-packages (0.10.1)
# Requirement already satisfied: joblib>=0.11 in /opt/anaconda3/lib/python3.11/site-packages (from scikit-optimize) (1.2.0)
# Requirement already satisfied: pyaml>=16.9 in /opt/anaconda3/lib/python3.11/site-packages (from scikit-optimize) (23.12.0)
# Requirement already satisfied: numpy>=1.20.3 in /opt/anaconda3/lib/python3.11/site-packages (from scikit-optimize) (1.26.4)
# Requirement already satisfied: scipy>=1.1.0 in /opt/anaconda3/lib/python3.11/site-packages (from scikit-optimize) (1.11.4)
# Requirement already satisfied: scikit-learn>=1.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from scikit-optimize) (1.4.2)
# Requirement already satisfied: packaging>=21.3 in /opt/anaconda3/lib/python3.11/site-packages (from scikit-optimize) (23.1)
# Requirement already satisfied: PyYAML in /opt/anaconda3/lib/python3.11/site-packages (from pyaml>=16.9->scikit-optimize) (6.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from scikit-learn>=1.0.0->scikit-optimize) (2.2.0)
# Requirement already satisfied: scipy in /opt/anaconda3/lib/python3.11/site-packages (1.11.4)
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in /opt/anaconda3/lib/python3.11/site-packages (from scipy) (1.26.4)

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# import modules
# packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time
import seaborn as sns
import nltk
import re
import joblib
import contractions
import scipy.stats

# modules preprocessing
from matplotlib.ticker import FormatStrFormatter 
from matplotlib.colors import LinearSegmentedColormap
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
nltk.download('stopwords')
from wordcloud import WordCloud
from collections import Counter
from unidecode import unidecode
from nltk.corpus import stopwords
nltk.download('wordnet')
nltk.download('punkt')
import contractions
from scipy.stats import randint, uniform

# sentiment & transforming features
from textblob import TextBlob
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OrdinalEncoder
from sklearn.feature_extraction.text import TfidfVectorizer
from imblearn.under_sampling import RandomUnderSampler

# algorithms
from sklearn.ensemble import RandomForestClassifier
# import lightgbm as lgb
from sklearn.svm import SVC

# evaluation
from sklearn.model_selection import train_test_split
from sklearn.metrics import cohen_kappa_score, mean_absolute_error,  mean_squared_error
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/sebastianhaecker/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/sebastianhaecker/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/sebastianhaecker/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# # Load clean data

# %%
df = pd.read_csv('clean_data.csv', index_col=0)
# df = pd.read_csv('/content/drive/MyDrive/3_classes/clean_data.csv', index_col=0)  # running lightgbm in colab

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 75790 entries, 0 to 362281
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Age        75790 non-null  object
#  1   Reviews    75790 non-null  object
#  2   Sex        75790 non-null  object
#  3   EaseofUse  75790 non-null  int64
# dtypes: int64(1), object(3)
# memory usage: 2.9+ MB

# %% [markdown]
# ## Textblob Polarity Score

# %%
# # Textblob on the reviews to extract sentiment: the polarity score, RUN ONLY WHEN TESTED WITH POLARITY SCORE
sentiment_scores = df['Reviews'].apply(lambda x: TextBlob(x).sentiment)
polarity_scores = sentiment_scores.apply(lambda x: x.polarity)
# Add polarity scores as predictive features
df['Polarity_score_review'] = polarity_scores

# %% [markdown]
# ### Train/Test split

# %%
# Split data in train and test
train, test = train_test_split(df, test_size=0.1, random_state=42, stratify=df['EaseofUse'])

# %%
print(train.info())
print(test.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 68211 entries, 233007 to 200930
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Age                    68211 non-null  object
#  1   Reviews                68211 non-null  object
#  2   Sex                    68211 non-null  object
#  3   EaseofUse              68211 non-null  int64
#  4   Polarity_score_review  68211 non-null  float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 3.1+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# Index: 7579 entries, 211222 to 44054
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Age                    7579 non-null   object
#  1   Reviews                7579 non-null   object
#  2   Sex                    7579 non-null   object
#  3   EaseofUse              7579 non-null   int64
#  4   Polarity_score_review  7579 non-null   float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 355.3+ KB
# None

# %% [markdown]
# ### Drop features 3th experiment

# %%
# Drop features for experiment 3, DROP ONLY WHEN TESTED WITHOUT ADDITIONAL FEATURES 
train.drop(columns=['Age', 'Sex'], inplace= True)
test.drop(columns=['Age', 'Sex'], inplace= True)

# %% [markdown]
# ## Undersample train set

# %%
# Class imbalance Undersampling the data distribution with RandomUnderSampler
X_train = train.drop(columns=['EaseofUse'])
y_train = train['EaseofUse']
rus = RandomUnderSampler(sampling_strategy='not minority', random_state=42)
X_train_resampled, y_train_resampled = rus.fit_resample(X_train, y_train)

train = pd.DataFrame(X_train_resampled, columns=X_train.columns)
train['EaseofUse'] = y_train_resampled
print(train.EaseofUse.value_counts())
# Out:
# EaseofUse
# 1    7422
# 2    7422
# 3    7422
# Name: count, dtype: int64

# %%
print(train.info())
print(test.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22266 entries, 183081 to 193215
# Data columns (total 3 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Reviews                22266 non-null  object
#  1   Polarity_score_review  22266 non-null  float64
#  2   EaseofUse              22266 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 695.8+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Index: 7579 entries, 211222 to 44054
# Data columns (total 3 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Reviews                7579 non-null   object
#  1   EaseofUse              7579 non-null   int64
#  2   Polarity_score_review  7579 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 236.8+ KB
# None

# %% [markdown]
# ### Transform features

# %%
# Encode categorical features with dummies encoding en label encoding RUN ONLY WHEN TESTING WITH FEATURES FROM DATASET
# train = pd.get_dummies(train, columns=['Sex'])
# test = pd.get_dummies(test, columns=['Sex'])

# ordinal_encoder = OrdinalEncoder()
# train['Age'] = ordinal_encoder.fit_transform(train[['Age']])
# test['Age'] = ordinal_encoder.transform(test[['Age']])

# %%
print(train.info())
print(test.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22266 entries, 183081 to 193215
# Data columns (total 3 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Reviews                22266 non-null  object
#  1   Polarity_score_review  22266 non-null  float64
#  2   EaseofUse              22266 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 695.8+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Index: 7579 entries, 211222 to 44054
# Data columns (total 3 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Reviews                7579 non-null   object
#  1   EaseofUse              7579 non-null   int64
#  2   Polarity_score_review  7579 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 236.8+ KB
# None

# %%
# Apply TF-IDF and ngrams on the review fature to be processed, CHANGE SETTING WHEN RUNNING UNIGRAMS, BIGRAMS OR TOGHETHER 
# tfidf_vectorizer = TfidfVectorizer(use_idf= True,smooth_idf = False, min_df= 0.005) #default
# tfidf_vectorizer = TfidfVectorizer(ngram_range=(1,1),smooth_idf = False, min_df= 0.005) #unigrams 
tfidf_vectorizer = TfidfVectorizer(ngram_range=(1,2), use_idf= True,smooth_idf = False, min_df= 0.005) #unigrams and bigrams

# Transform reviews
tfidf_train = tfidf_vectorizer.fit_transform(train['Reviews'])
tfidf_test = tfidf_vectorizer.transform(test['Reviews'])

# Convert to dataframe
X_train_text = pd.DataFrame(tfidf_train.toarray(), columns=tfidf_vectorizer.get_feature_names_out(), index=train.index)
X_test_text = pd.DataFrame(tfidf_test.toarray(), columns=tfidf_vectorizer.get_feature_names_out(), index=test.index)

# Concatenate and make dataframe
train = pd.concat([train.drop(columns='Reviews'), X_train_text], axis=1)
test = pd.concat([test.drop(columns='Reviews'), X_test_text], axis=1)

# %%
print (train.shape)
print (test.shape)
# Out:
# (22266, 1099)
# (7579, 1099)

# %%
# Split the train and test set for prediction in: X_train, y_train, X_test, y_test
X_train = train.drop(columns=['EaseofUse'])
y_train = train['EaseofUse']
X_test = test.drop(columns=['EaseofUse'])
y_test = test['EaseofUse']

# %%
print (X_train.shape)
print (y_train.shape)
print (X_test.shape)
print (y_test.shape)
# Out:
# (22266, 1098)
# (22266,)
# (7579, 1098)
# (7579,)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22266 entries, 183081 to 193215
# Columns: 1098 entries, Polarity_score_review to zero
# dtypes: float64(1098)
# memory usage: 186.7 MB

# %% [markdown]
# ## RF model with unigrams, bigrams + polarity score without features 'Age', 'Gender'

# %%
# Hyperparameter tuning: Randomized search
start_time = time.time()

param_grid = {
    'n_estimators': randint(10, 1000),
    'max_depth': randint(1, 60),
    'min_samples_split': randint(2, 10),
    'min_samples_leaf': randint(1, 10),
    'bootstrap' : [True, False],
    'criterion': ['gini', 'entropy'], 
}

k_fold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
rf_classifier = RandomForestClassifier(random_state=42)
rf_random = RandomizedSearchCV(estimator=rf_classifier,
                                   param_distributions=param_grid,
                                   n_iter=100,
                                   cv=k_fold,
                                   scoring = 'neg_mean_absolute_error',
                                   n_jobs=5,
                                   verbose = 3, 
                                   random_state=42)
rf_random.fit(X_train, y_train)

print("Best Parameters:", rf_random.best_params_)
print("Best score found: ",-rf_random.best_score_)
print ('Best estimator:', rf_random.best_estimator_)

end_time = time.time()
elapsed_time = end_time - start_time
hours, remainder = divmod(elapsed_time, 3600)
minutes, seconds = divmod(remainder, 60)
print(f"Execution time: {int(hours)} hours, {int(minutes)} minutes, {int(seconds)} seconds")
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV 1/5] END bootstrap=True, criterion=entropy, max_depth=29, min_samples_leaf=8, min_samples_split=6, n_estimators=30;, score=-0.682 total time=   2.6s
# [CV 4/5] END bootstrap=True, criterion=entropy, max_depth=19, min_samples_leaf=7, min_samples_split=4, n_estimators=468;, score=-0.669 total time=  20.1s
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=36, min_samples_leaf=8, min_samples_split=9, n_estimators=140;, score=-0.661 total time=  13.9s
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=2, min_samples_leaf=8, min_samples_split=5, n_estimators=423;, score=-0.728 total time=   3.5s
# [CV 5/5] END bootstrap=False, criterion=entropy, max_depth=21, min_samples_leaf=1, min_samples_split=5, n_estimators=323;, score=-0.689 total time=  28.3s
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=44, min_samples_leaf=9, min_samples_split=2, n_estimators=484;, score=-0.652 total time=  56.5s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=42, min_samples_leaf=3, min_samples_split=5, n_estimators=576;, score=-0.637 total time=  53.4s
# [CV 4/5] END bootstrap=False, criterion=entropy, max_depth=57, min_samples_leaf=3, min_samples_split=6, n_estimators=828;, score=-0.651 total time= 2.7min
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=9, min_samples_leaf=7, min_samples_split=3, n_estimators=397;, score=-0.699 total time=   9.4s
# [CV 5/5] END bootstrap=True, criterion=entropy, max_depth=14, min_samples_leaf=2, min_samples_split=3, n_estimators=786;, score=-0.691 total time=  32.4s
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=2, min_samples_leaf=4, min_samples_split=5, n_estimators=376;, score=-0.731 total time=   3.5s
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=44, min_samples_leaf=8, min_samples_split=8, n_estimators=44;, score=-0.676 total time=   5.6s
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=36, min_samples_leaf=2, min_samples_split=9, n_estimators=397;, score=-0.673 total time=  51.3s
# [CV 5/5] END bootstrap=False, criterion=entropy, max_depth=6, min_samples_leaf=6, min_samples_split=3, n_estimators=781;, score=-0.707 total time=  19.8s
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=18, min_samples_leaf=2, min_samples_split=3, n_estimators=967;, score=-0.685 total time= 1.1min
# [CV 5/5] END bootstrap=False, criterion=entropy, max_depth=31, min_samples_leaf=8, min_samples_split=7, n_estimators=736;, score=-0.688 total time= 1.3min
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=40, min_samples_leaf=5, min_samples_split=9, n_estimators=758;, score=-0.673 total time= 1.6min
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=53, min_samples_leaf=8, min_samples_split=3, n_estimators=226;, score=-0.686 total time=  29.9s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=25, min_samples_leaf=7, min_samples_split=2, n_estimators=353;, score=-0.658 total time=  19.4s
# [CV 1/5] END bootstrap=True, criterion=entropy, max_depth=8, min_samples_leaf=8, min_samples_split=8, n_estimators=148;, score=-0.699 total time=   3.7s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=8, min_samples_leaf=3, min_samples_split=4, n_estimators=298;, score=-0.685 total time=   6.2s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=42, min_samples_leaf=7, min_samples_split=3, n_estimators=50;, score=-0.654 total time=   3.9s
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=9, min_samples_leaf=8, min_samples_split=5, n_estimators=939;, score=-0.687 total time=  29.5s
# [CV 1/5] END bootstrap=True, criterion=entropy, max_depth=55, min_samples_leaf=7, min_samples_split=7, n_estimators=737;, score=-0.659 total time= 1.2min
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=44, min_samples_leaf=8, min_samples_split=7, n_estimators=996;, score=-0.652 total time= 1.3min
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=35, min_samples_leaf=5, min_samples_split=8, n_estimators=471;, score=-0.653 total time=  35.0s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=5, min_samples_leaf=7, min_samples_split=8, n_estimators=407;, score=-0.690 total time=   5.7s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=9, min_samples_leaf=3, min_samples_split=8, n_estimators=873;, score=-0.678 total time=  19.9s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=52, min_samples_leaf=4, min_samples_split=7, n_estimators=494;, score=-0.645 total time=  48.5s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=45, min_samples_leaf=4, min_samples_split=6, n_estimators=169;, score=-0.648 total time=  15.5s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=51, min_samples_leaf=6, min_samples_split=5, n_estimators=587;, score=-0.649 total time=  52.9s
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=57, min_samples_leaf=5, min_samples_split=7, n_estimators=805;, score=-0.649 total time= 2.1min
# [CV 1/5] END bootstrap=False, criterion=entropy, max_depth=44, min_samples_leaf=4, min_samples_split=7, n_estimators=967;, score=-0.649 total time= 2.6min
# [CV 1/5] END bootstrap=True, criterion=entropy, max_depth=58, min_samples_leaf=7, min_samples_split=5, n_estimators=482;, score=-0.656 total time=  50.5s
# [CV 1/5] END bootstrap=True, criterion=entropy, max_depth=33, min_samples_leaf=1, min_samples_split=2, n_estimators=292;, score=-0.659 total time=  27.9s
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=52, min_samples_leaf=9, min_samples_split=4, n_estimators=368;, score=-0.661 total time=  47.6s
# [CV 1/5] END bootstrap=False, criterion=entropy, max_depth=27, min_samples_leaf=9, min_samples_split=7, n_estimators=686;, score=-0.669 total time= 1.1min
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=42, min_samples_leaf=8, min_samples_split=8, n_estimators=836;, score=-0.652 total time= 1.1min
# [CV 1/5] END bootstrap=False, criterion=entropy, max_depth=32, min_samples_leaf=8, min_samples_split=2, n_estimators=701;, score=-0.666 total time= 1.3min
# [CV 1/5] END bootstrap=True, criterion=entropy, max_depth=49, min_samples_leaf=4, min_samples_split=5, n_estimators=519;, score=-0.652 total time=  55.6s
# [CV 1/5] END bootstrap=True, criterion=entropy, max_depth=3, min_samples_leaf=1, min_samples_split=6, n_estimators=634;, score=-0.700 total time=   6.8s
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=59, min_samples_leaf=1, min_samples_split=3, n_estimators=651;, score=-0.649 total time= 2.2min
# /opt/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:700: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [CV 3/5] END bootstrap=True, criterion=entropy, max_depth=29, min_samples_leaf=8, min_samples_split=6, n_estimators=30;, score=-0.656 total time=   2.6s
# [CV 2/5] END bootstrap=True, criterion=entropy, max_depth=19, min_samples_leaf=7, min_samples_split=4, n_estimators=468;, score=-0.667 total time=  20.1s
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=36, min_samples_leaf=8, min_samples_split=9, n_estimators=140;, score=-0.641 total time=  14.0s
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=2, min_samples_leaf=8, min_samples_split=5, n_estimators=423;, score=-0.697 total time=   3.5s
# [CV 4/5] END bootstrap=False, criterion=entropy, max_depth=21, min_samples_leaf=1, min_samples_split=5, n_estimators=323;, score=-0.664 total time=  28.3s
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=44, min_samples_leaf=9, min_samples_split=2, n_estimators=484;, score=-0.675 total time=  56.5s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=42, min_samples_leaf=3, min_samples_split=5, n_estimators=576;, score=-0.649 total time=  53.2s
# [CV 3/5] END bootstrap=False, criterion=entropy, max_depth=57, min_samples_leaf=3, min_samples_split=6, n_estimators=828;, score=-0.635 total time= 2.7min
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=9, min_samples_leaf=7, min_samples_split=3, n_estimators=397;, score=-0.675 total time=   9.4s
# [CV 4/5] END bootstrap=True, criterion=entropy, max_depth=14, min_samples_leaf=2, min_samples_split=3, n_estimators=786;, score=-0.667 total time=  32.3s
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=2, min_samples_leaf=4, min_samples_split=5, n_estimators=376;, score=-0.714 total time=   3.4s
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=44, min_samples_leaf=8, min_samples_split=8, n_estimators=44;, score=-0.657 total time=   5.5s
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=36, min_samples_leaf=2, min_samples_split=9, n_estimators=397;, score=-0.652 total time=  51.3s
# [CV 4/5] END bootstrap=False, criterion=entropy, max_depth=6, min_samples_leaf=6, min_samples_split=3, n_estimators=781;, score=-0.690 total time=  19.7s
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=18, min_samples_leaf=2, min_samples_split=3, n_estimators=967;, score=-0.660 total time= 1.1min
# [CV 4/5] END bootstrap=False, criterion=entropy, max_depth=31, min_samples_leaf=8, min_samples_split=7, n_estimators=736;, score=-0.660 total time= 1.3min
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=40, min_samples_leaf=5, min_samples_split=9, n_estimators=758;, score=-0.632 total time= 1.6min
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=53, min_samples_leaf=8, min_samples_split=3, n_estimators=226;, score=-0.631 total time=  29.9s
# [CV 3/5] END bootstrap=False, criterion=entropy, max_depth=45, min_samples_leaf=9, min_samples_split=6, n_estimators=24;, score=-0.651 total time=   3.4s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=25, min_samples_leaf=7, min_samples_split=2, n_estimators=353;, score=-0.647 total time=  19.4s
# [CV 3/5] END bootstrap=True, criterion=entropy, max_depth=8, min_samples_leaf=8, min_samples_split=8, n_estimators=148;, score=-0.676 total time=   3.5s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=8, min_samples_leaf=3, min_samples_split=4, n_estimators=298;, score=-0.676 total time=   6.1s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=42, min_samples_leaf=7, min_samples_split=3, n_estimators=50;, score=-0.632 total time=   4.0s
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=9, min_samples_leaf=8, min_samples_split=5, n_estimators=939;, score=-0.671 total time=  29.3s
# [CV 3/5] END bootstrap=True, criterion=entropy, max_depth=55, min_samples_leaf=7, min_samples_split=7, n_estimators=737;, score=-0.635 total time= 1.2min
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=44, min_samples_leaf=8, min_samples_split=7, n_estimators=996;, score=-0.633 total time= 1.3min
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=35, min_samples_leaf=5, min_samples_split=8, n_estimators=471;, score=-0.637 total time=  35.1s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=5, min_samples_leaf=7, min_samples_split=8, n_estimators=407;, score=-0.682 total time=   5.6s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=9, min_samples_leaf=3, min_samples_split=8, n_estimators=873;, score=-0.671 total time=  20.0s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=52, min_samples_leaf=4, min_samples_split=7, n_estimators=494;, score=-0.628 total time=  48.9s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=45, min_samples_leaf=4, min_samples_split=6, n_estimators=169;, score=-0.637 total time=  15.6s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=51, min_samples_leaf=6, min_samples_split=5, n_estimators=587;, score=-0.630 total time=  52.9s
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=57, min_samples_leaf=5, min_samples_split=7, n_estimators=805;, score=-0.627 total time= 2.2min
# [CV 4/5] END bootstrap=False, criterion=entropy, max_depth=44, min_samples_leaf=4, min_samples_split=7, n_estimators=967;, score=-0.654 total time= 2.6min
# [CV 4/5] END bootstrap=True, criterion=entropy, max_depth=58, min_samples_leaf=7, min_samples_split=5, n_estimators=482;, score=-0.653 total time=  50.3s
# [CV 4/5] END bootstrap=True, criterion=entropy, max_depth=33, min_samples_leaf=1, min_samples_split=2, n_estimators=292;, score=-0.659 total time=  27.8s
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=52, min_samples_leaf=9, min_samples_split=4, n_estimators=368;, score=-0.658 total time=  47.5s
# [CV 4/5] END bootstrap=False, criterion=entropy, max_depth=27, min_samples_leaf=9, min_samples_split=7, n_estimators=686;, score=-0.661 total time= 1.1min
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=42, min_samples_leaf=8, min_samples_split=8, n_estimators=836;, score=-0.658 total time= 1.1min
# [CV 2/5] END bootstrap=False, criterion=entropy, max_depth=32, min_samples_leaf=8, min_samples_split=2, n_estimators=701;, score=-0.669 total time= 1.3min
# [CV 2/5] END bootstrap=True, criterion=entropy, max_depth=49, min_samples_leaf=4, min_samples_split=5, n_estimators=519;, score=-0.662 total time=  55.4s
# [CV 2/5] END bootstrap=True, criterion=entropy, max_depth=3, min_samples_leaf=1, min_samples_split=6, n_estimators=634;, score=-0.706 total time=   6.7s
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=59, min_samples_leaf=1, min_samples_split=3, n_estimators=651;, score=-0.656 total time= 2.2min
# [CV 4/5] END bootstrap=True, criterion=entropy, max_depth=29, min_samples_leaf=8, min_samples_split=6, n_estimators=30;, score=-0.673 total time=   2.6s
# [CV 5/5] END bootstrap=True, criterion=entropy, max_depth=19, min_samples_leaf=7, min_samples_split=4, n_estimators=468;, score=-0.683 total time=  20.2s
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=36, min_samples_leaf=8, min_samples_split=9, n_estimators=140;, score=-0.682 total time=  13.8s
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=2, min_samples_leaf=8, min_samples_split=5, n_estimators=423;, score=-0.718 total time=   3.4s
# [CV 3/5] END bootstrap=False, criterion=entropy, max_depth=21, min_samples_leaf=1, min_samples_split=5, n_estimators=323;, score=-0.655 total time=  28.3s
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=44, min_samples_leaf=9, min_samples_split=2, n_estimators=484;, score=-0.634 total time=  56.8s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=42, min_samples_leaf=3, min_samples_split=5, n_estimators=576;, score=-0.670 total time=  53.2s
# [CV 5/5] END bootstrap=False, criterion=entropy, max_depth=57, min_samples_leaf=3, min_samples_split=6, n_estimators=828;, score=-0.671 total time= 2.7min
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=9, min_samples_leaf=7, min_samples_split=3, n_estimators=397;, score=-0.676 total time=   9.2s
# [CV 3/5] END bootstrap=True, criterion=entropy, max_depth=14, min_samples_leaf=2, min_samples_split=3, n_estimators=786;, score=-0.661 total time=  32.2s
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=2, min_samples_leaf=4, min_samples_split=5, n_estimators=376;, score=-0.695 total time=   3.4s
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=44, min_samples_leaf=8, min_samples_split=8, n_estimators=44;, score=-0.636 total time=   5.5s
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=36, min_samples_leaf=2, min_samples_split=9, n_estimators=397;, score=-0.633 total time=  51.2s
# [CV 3/5] END bootstrap=False, criterion=entropy, max_depth=6, min_samples_leaf=6, min_samples_split=3, n_estimators=781;, score=-0.690 total time=  19.7s
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=18, min_samples_leaf=2, min_samples_split=3, n_estimators=967;, score=-0.653 total time= 1.1min
# [CV 3/5] END bootstrap=False, criterion=entropy, max_depth=31, min_samples_leaf=8, min_samples_split=7, n_estimators=736;, score=-0.648 total time= 1.3min
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=40, min_samples_leaf=5, min_samples_split=9, n_estimators=758;, score=-0.653 total time= 1.6min
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=53, min_samples_leaf=8, min_samples_split=3, n_estimators=226;, score=-0.656 total time=  29.8s
# [CV 4/5] END bootstrap=False, criterion=entropy, max_depth=45, min_samples_leaf=9, min_samples_split=6, n_estimators=24;, score=-0.664 total time=   3.4s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=25, min_samples_leaf=7, min_samples_split=2, n_estimators=353;, score=-0.658 total time=  19.4s
# [CV 4/5] END bootstrap=True, criterion=entropy, max_depth=8, min_samples_leaf=8, min_samples_split=8, n_estimators=148;, score=-0.673 total time=   3.5s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=8, min_samples_leaf=3, min_samples_split=4, n_estimators=298;, score=-0.683 total time=   6.2s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=42, min_samples_leaf=7, min_samples_split=3, n_estimators=50;, score=-0.647 total time=   4.0s
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=9, min_samples_leaf=8, min_samples_split=5, n_estimators=939;, score=-0.676 total time=  29.5s
# [CV 4/5] END bootstrap=True, criterion=entropy, max_depth=55, min_samples_leaf=7, min_samples_split=7, n_estimators=737;, score=-0.654 total time= 1.2min
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=44, min_samples_leaf=8, min_samples_split=7, n_estimators=996;, score=-0.653 total time= 1.3min
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=35, min_samples_leaf=5, min_samples_split=8, n_estimators=471;, score=-0.655 total time=  35.4s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=5, min_samples_leaf=7, min_samples_split=8, n_estimators=407;, score=-0.702 total time=   5.5s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=9, min_samples_leaf=3, min_samples_split=8, n_estimators=873;, score=-0.696 total time=  20.0s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=52, min_samples_leaf=4, min_samples_split=7, n_estimators=494;, score=-0.651 total time=  48.8s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=45, min_samples_leaf=4, min_samples_split=6, n_estimators=169;, score=-0.682 total time=  15.6s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=51, min_samples_leaf=6, min_samples_split=5, n_estimators=587;, score=-0.674 total time=  53.1s
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=57, min_samples_leaf=5, min_samples_split=7, n_estimators=805;, score=-0.671 total time= 2.2min
# [CV 5/5] END bootstrap=False, criterion=entropy, max_depth=44, min_samples_leaf=4, min_samples_split=7, n_estimators=967;, score=-0.679 total time= 2.6min
# [CV 5/5] END bootstrap=True, criterion=entropy, max_depth=58, min_samples_leaf=7, min_samples_split=5, n_estimators=482;, score=-0.675 total time=  50.5s
# [CV 5/5] END bootstrap=True, criterion=entropy, max_depth=33, min_samples_leaf=1, min_samples_split=2, n_estimators=292;, score=-0.681 total time=  28.0s
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=52, min_samples_leaf=9, min_samples_split=4, n_estimators=368;, score=-0.675 total time=  47.8s
# [CV 5/5] END bootstrap=False, criterion=entropy, max_depth=27, min_samples_leaf=9, min_samples_split=7, n_estimators=686;, score=-0.693 total time= 1.1min
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=42, min_samples_leaf=8, min_samples_split=8, n_estimators=836;, score=-0.668 total time= 1.1min
# [CV 5/5] END bootstrap=False, criterion=entropy, max_depth=32, min_samples_leaf=8, min_samples_split=2, n_estimators=701;, score=-0.691 total time= 1.3min
# [CV 5/5] END bootstrap=True, criterion=entropy, max_depth=49, min_samples_leaf=4, min_samples_split=5, n_estimators=519;, score=-0.667 total time=  55.6s
# [CV 5/5] END bootstrap=True, criterion=entropy, max_depth=3, min_samples_leaf=1, min_samples_split=6, n_estimators=634;, score=-0.723 total time=   7.0s
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=59, min_samples_leaf=1, min_samples_split=3, n_estimators=651;, score=-0.664 total time= 2.2min
# [CV 5/5] END bootstrap=True, criterion=entropy, max_depth=29, min_samples_leaf=8, min_samples_split=6, n_estimators=30;, score=-0.689 total time=   2.6s
# [CV 3/5] END bootstrap=True, criterion=entropy, max_depth=19, min_samples_leaf=7, min_samples_split=4, n_estimators=468;, score=-0.661 total time=  19.9s
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=36, min_samples_leaf=8, min_samples_split=9, n_estimators=140;, score=-0.665 total time=  13.9s
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=2, min_samples_leaf=8, min_samples_split=5, n_estimators=423;, score=-0.712 total time=   3.3s
# [CV 2/5] END bootstrap=False, criterion=entropy, max_depth=21, min_samples_leaf=1, min_samples_split=5, n_estimators=323;, score=-0.671 total time=  28.1s
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=44, min_samples_leaf=9, min_samples_split=2, n_estimators=484;, score=-0.655 total time=  56.4s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=42, min_samples_leaf=3, min_samples_split=5, n_estimators=576;, score=-0.657 total time=  53.5s
# [CV 2/5] END bootstrap=False, criterion=entropy, max_depth=57, min_samples_leaf=3, min_samples_split=6, n_estimators=828;, score=-0.662 total time= 2.7min
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=9, min_samples_leaf=7, min_samples_split=3, n_estimators=397;, score=-0.682 total time=   9.3s
# [CV 2/5] END bootstrap=True, criterion=entropy, max_depth=14, min_samples_leaf=2, min_samples_split=3, n_estimators=786;, score=-0.675 total time=  32.1s
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=2, min_samples_leaf=4, min_samples_split=5, n_estimators=376;, score=-0.714 total time=   3.4s
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=44, min_samples_leaf=8, min_samples_split=8, n_estimators=44;, score=-0.656 total time=   5.6s
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=36, min_samples_leaf=2, min_samples_split=9, n_estimators=397;, score=-0.654 total time=  51.1s
# [CV 2/5] END bootstrap=False, criterion=entropy, max_depth=6, min_samples_leaf=6, min_samples_split=3, n_estimators=781;, score=-0.698 total time=  19.7s
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=18, min_samples_leaf=2, min_samples_split=3, n_estimators=967;, score=-0.665 total time= 1.1min
# [CV 2/5] END bootstrap=False, criterion=entropy, max_depth=31, min_samples_leaf=8, min_samples_split=7, n_estimators=736;, score=-0.667 total time= 1.3min
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=40, min_samples_leaf=5, min_samples_split=9, n_estimators=758;, score=-0.656 total time= 1.6min
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=53, min_samples_leaf=8, min_samples_split=3, n_estimators=226;, score=-0.650 total time=  29.9s
# [CV 2/5] END bootstrap=False, criterion=entropy, max_depth=45, min_samples_leaf=9, min_samples_split=6, n_estimators=24;, score=-0.664 total time=   3.4s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=25, min_samples_leaf=7, min_samples_split=2, n_estimators=353;, score=-0.664 total time=  19.4s
# [CV 2/5] END bootstrap=True, criterion=entropy, max_depth=8, min_samples_leaf=8, min_samples_split=8, n_estimators=148;, score=-0.690 total time=   3.7s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=8, min_samples_leaf=3, min_samples_split=4, n_estimators=298;, score=-0.681 total time=   6.2s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=42, min_samples_leaf=7, min_samples_split=3, n_estimators=50;, score=-0.649 total time=   3.9s
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=9, min_samples_leaf=8, min_samples_split=5, n_estimators=939;, score=-0.677 total time=  29.3s
# [CV 2/5] END bootstrap=True, criterion=entropy, max_depth=55, min_samples_leaf=7, min_samples_split=7, n_estimators=737;, score=-0.658 total time= 1.2min
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=44, min_samples_leaf=8, min_samples_split=7, n_estimators=996;, score=-0.656 total time= 1.3min
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=35, min_samples_leaf=5, min_samples_split=8, n_estimators=471;, score=-0.660 total time=  35.1s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=5, min_samples_leaf=7, min_samples_split=8, n_estimators=407;, score=-0.683 total time=   5.6s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=9, min_samples_leaf=3, min_samples_split=8, n_estimators=873;, score=-0.675 total time=  19.9s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=52, min_samples_leaf=4, min_samples_split=7, n_estimators=494;, score=-0.656 total time=  48.7s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=45, min_samples_leaf=4, min_samples_split=6, n_estimators=169;, score=-0.649 total time=  15.5s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=51, min_samples_leaf=6, min_samples_split=5, n_estimators=587;, score=-0.653 total time=  52.8s
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=57, min_samples_leaf=5, min_samples_split=7, n_estimators=805;, score=-0.658 total time= 2.2min
# [CV 2/5] END bootstrap=False, criterion=entropy, max_depth=44, min_samples_leaf=4, min_samples_split=7, n_estimators=967;, score=-0.667 total time= 2.6min
# [CV 2/5] END bootstrap=True, criterion=entropy, max_depth=58, min_samples_leaf=7, min_samples_split=5, n_estimators=482;, score=-0.665 total time=  50.0s
# [CV 2/5] END bootstrap=True, criterion=entropy, max_depth=33, min_samples_leaf=1, min_samples_split=2, n_estimators=292;, score=-0.664 total time=  28.0s
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=52, min_samples_leaf=9, min_samples_split=4, n_estimators=368;, score=-0.660 total time=  47.8s
# [CV 2/5] END bootstrap=False, criterion=entropy, max_depth=27, min_samples_leaf=9, min_samples_split=7, n_estimators=686;, score=-0.666 total time= 1.1min
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=42, min_samples_leaf=8, min_samples_split=8, n_estimators=836;, score=-0.659 total time= 1.1min
# [CV 4/5] END bootstrap=False, criterion=entropy, max_depth=32, min_samples_leaf=8, min_samples_split=2, n_estimators=701;, score=-0.658 total time= 1.3min
# [CV 4/5] END bootstrap=True, criterion=entropy, max_depth=49, min_samples_leaf=4, min_samples_split=5, n_estimators=519;, score=-0.650 total time=  55.7s
# [CV 4/5] END bootstrap=True, criterion=entropy, max_depth=3, min_samples_leaf=1, min_samples_split=6, n_estimators=634;, score=-0.692 total time=   6.7s
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=59, min_samples_leaf=1, min_samples_split=3, n_estimators=651;, score=-0.645 total time= 2.2min
# [CV 4/5] END bootstrap=False, criterion=entropy, max_depth=23, min_samples_leaf=5, min_samples_split=9, n_estimators=234;, score=-0.662 total time=  21.8s
# [CV 1/5] END bootstrap=False, criterion=entropy, max_depth=23, min_samples_leaf=5, min_samples_split=9, n_estimators=234;, score=-0.663 total time=  21.8s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=5, n_estimators=739;, score=-0.699 total time=   5.0s
# [CV 1/5] END bootstrap=False, criterion=entropy, max_depth=32, min_samples_leaf=7, min_samples_split=5, n_estimators=448;, score=-0.664 total time=  51.9s
# [CV 1/5] END bootstrap=True, criterion=entropy, max_depth=59, min_samples_leaf=1, min_samples_split=8, n_estimators=303;, score=-0.652 total time=  44.0s
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=52, min_samples_leaf=2, min_samples_split=7, n_estimators=991;, score=-0.650 total time= 2.8min
# [CV 2/5] END bootstrap=False, criterion=entropy, max_depth=23, min_samples_leaf=5, min_samples_split=9, n_estimators=234;, score=-0.667 total time=  21.7s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=5, n_estimators=739;, score=-0.691 total time=   5.0s
# [CV 3/5] END bootstrap=False, criterion=entropy, max_depth=32, min_samples_leaf=7, min_samples_split=5, n_estimators=448;, score=-0.646 total time=  52.1s
# [CV 3/5] END bootstrap=True, criterion=entropy, max_depth=59, min_samples_leaf=1, min_samples_split=8, n_estimators=303;, score=-0.642 total time=  43.8s
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=52, min_samples_leaf=2, min_samples_split=7, n_estimators=991;, score=-0.660 total time= 2.8min
# [CV 2/5] END bootstrap=True, criterion=entropy, max_depth=29, min_samples_leaf=8, min_samples_split=6, n_estimators=30;, score=-0.662 total time=   2.6s
# [CV 1/5] END bootstrap=True, criterion=entropy, max_depth=19, min_samples_leaf=7, min_samples_split=4, n_estimators=468;, score=-0.671 total time=  19.8s
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=36, min_samples_leaf=8, min_samples_split=9, n_estimators=140;, score=-0.654 total time=  13.9s
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=2, min_samples_leaf=8, min_samples_split=5, n_estimators=423;, score=-0.708 total time=   3.3s
# [CV 1/5] END bootstrap=False, criterion=entropy, max_depth=21, min_samples_leaf=1, min_samples_split=5, n_estimators=323;, score=-0.667 total time=  28.1s
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=44, min_samples_leaf=9, min_samples_split=2, n_estimators=484;, score=-0.652 total time=  56.1s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=42, min_samples_leaf=3, min_samples_split=5, n_estimators=576;, score=-0.652 total time=  53.1s
# [CV 1/5] END bootstrap=False, criterion=entropy, max_depth=57, min_samples_leaf=3, min_samples_split=6, n_estimators=828;, score=-0.654 total time= 2.7min
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=9, min_samples_leaf=7, min_samples_split=3, n_estimators=397;, score=-0.684 total time=   9.3s
# [CV 1/5] END bootstrap=True, criterion=entropy, max_depth=14, min_samples_leaf=2, min_samples_split=3, n_estimators=786;, score=-0.672 total time=  32.2s
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=2, min_samples_leaf=4, min_samples_split=5, n_estimators=376;, score=-0.710 total time=   3.3s
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=44, min_samples_leaf=8, min_samples_split=8, n_estimators=44;, score=-0.653 total time=   5.5s
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=36, min_samples_leaf=2, min_samples_split=9, n_estimators=397;, score=-0.656 total time=  51.2s
# [CV 1/5] END bootstrap=False, criterion=entropy, max_depth=6, min_samples_leaf=6, min_samples_split=3, n_estimators=781;, score=-0.700 total time=  19.7s
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=18, min_samples_leaf=2, min_samples_split=3, n_estimators=967;, score=-0.664 total time= 1.1min
# [CV 1/5] END bootstrap=False, criterion=entropy, max_depth=31, min_samples_leaf=8, min_samples_split=7, n_estimators=736;, score=-0.664 total time= 1.3min
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=40, min_samples_leaf=5, min_samples_split=9, n_estimators=758;, score=-0.652 total time= 1.6min
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=53, min_samples_leaf=8, min_samples_split=3, n_estimators=226;, score=-0.660 total time=  29.7s
# [CV 1/5] END bootstrap=False, criterion=entropy, max_depth=45, min_samples_leaf=9, min_samples_split=6, n_estimators=24;, score=-0.659 total time=   3.4s
# [CV 5/5] END bootstrap=False, criterion=entropy, max_depth=45, min_samples_leaf=9, min_samples_split=6, n_estimators=24;, score=-0.690 total time=   3.4s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=25, min_samples_leaf=7, min_samples_split=2, n_estimators=353;, score=-0.674 total time=  19.3s
# [CV 5/5] END bootstrap=True, criterion=entropy, max_depth=8, min_samples_leaf=8, min_samples_split=8, n_estimators=148;, score=-0.707 total time=   3.5s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=8, min_samples_leaf=3, min_samples_split=4, n_estimators=298;, score=-0.695 total time=   6.1s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=42, min_samples_leaf=7, min_samples_split=3, n_estimators=50;, score=-0.672 total time=   3.9s
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=9, min_samples_leaf=8, min_samples_split=5, n_estimators=939;, score=-0.699 total time=  29.3s
# [CV 5/5] END bootstrap=True, criterion=entropy, max_depth=55, min_samples_leaf=7, min_samples_split=7, n_estimators=737;, score=-0.674 total time= 1.2min
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=44, min_samples_leaf=8, min_samples_split=7, n_estimators=996;, score=-0.674 total time= 1.3min
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=35, min_samples_leaf=5, min_samples_split=8, n_estimators=471;, score=-0.670 total time=  35.0s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=5, min_samples_leaf=7, min_samples_split=8, n_estimators=407;, score=-0.683 total time=   5.6s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=9, min_samples_leaf=3, min_samples_split=8, n_estimators=873;, score=-0.671 total time=  20.1s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=52, min_samples_leaf=4, min_samples_split=7, n_estimators=494;, score=-0.670 total time=  48.6s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=45, min_samples_leaf=4, min_samples_split=6, n_estimators=169;, score=-0.655 total time=  15.5s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=51, min_samples_leaf=6, min_samples_split=5, n_estimators=587;, score=-0.655 total time=  52.8s
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=57, min_samples_leaf=5, min_samples_split=7, n_estimators=805;, score=-0.648 total time= 2.2min
# [CV 3/5] END bootstrap=False, criterion=entropy, max_depth=44, min_samples_leaf=4, min_samples_split=7, n_estimators=967;, score=-0.638 total time= 2.6min
# [CV 3/5] END bootstrap=True, criterion=entropy, max_depth=58, min_samples_leaf=7, min_samples_split=5, n_estimators=482;, score=-0.638 total time=  50.4s
# [CV 3/5] END bootstrap=True, criterion=entropy, max_depth=33, min_samples_leaf=1, min_samples_split=2, n_estimators=292;, score=-0.643 total time=  27.8s
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=52, min_samples_leaf=9, min_samples_split=4, n_estimators=368;, score=-0.631 total time=  47.7s
# [CV 3/5] END bootstrap=False, criterion=entropy, max_depth=27, min_samples_leaf=9, min_samples_split=7, n_estimators=686;, score=-0.652 total time= 1.1min
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=42, min_samples_leaf=8, min_samples_split=8, n_estimators=836;, score=-0.634 total time= 1.1min
# [CV 3/5] END bootstrap=False, criterion=entropy, max_depth=32, min_samples_leaf=8, min_samples_split=2, n_estimators=701;, score=-0.649 total time= 1.3min
# [CV 3/5] END bootstrap=True, criterion=entropy, max_depth=49, min_samples_leaf=4, min_samples_split=5, n_estimators=519;, score=-0.634 total time=  55.5s
# [CV 3/5] END bootstrap=True, criterion=entropy, max_depth=3, min_samples_leaf=1, min_samples_split=6, n_estimators=634;, score=-0.688 total time=   6.8s
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=59, min_samples_leaf=1, min_samples_split=3, n_estimators=651;, score=-0.631 total time= 2.2min
# [CV 3/5] END bootstrap=False, criterion=entropy, max_depth=23, min_samples_leaf=5, min_samples_split=9, n_estimators=234;, score=-0.654 total time=  21.8s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=5, n_estimators=739;, score=-0.707 total time=   5.4s
# [CV 2/5] END bootstrap=False, criterion=entropy, max_depth=32, min_samples_leaf=7, min_samples_split=5, n_estimators=448;, score=-0.667 total time=  52.1s
# [CV 2/5] END bootstrap=True, criterion=entropy, max_depth=59, min_samples_leaf=1, min_samples_split=8, n_estimators=303;, score=-0.666 total time=  44.1s
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=52, min_samples_leaf=2, min_samples_split=7, n_estimators=991;, score=-0.635 total time= 2.8min
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=5, n_estimators=739;, score=-0.700 total time=   5.2s
# [CV 5/5] END bootstrap=False, criterion=entropy, max_depth=32, min_samples_leaf=7, min_samples_split=5, n_estimators=448;, score=-0.689 total time=  52.0s
# [CV 4/5] END bootstrap=True, criterion=entropy, max_depth=59, min_samples_leaf=1, min_samples_split=8, n_estimators=303;, score=-0.657 total time=  44.2s
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=52, min_samples_leaf=2, min_samples_split=7, n_estimators=991;, score=-0.644 total time= 2.8min
# [CV 5/5] END bootstrap=False, criterion=entropy, max_depth=23, min_samples_leaf=5, min_samples_split=9, n_estimators=234;, score=-0.682 total time=  21.5s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=5, n_estimators=739;, score=-0.720 total time=   5.2s
# [CV 4/5] END bootstrap=False, criterion=entropy, max_depth=32, min_samples_leaf=7, min_samples_split=5, n_estimators=448;, score=-0.653 total time=  52.2s
# [CV 5/5] END bootstrap=True, criterion=entropy, max_depth=59, min_samples_leaf=1, min_samples_split=8, n_estimators=303;, score=-0.671 total time=  44.3s
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=52, min_samples_leaf=2, min_samples_split=7, n_estimators=991;, score=-0.665 total time= 2.8min
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=48, min_samples_leaf=1, min_samples_split=2, n_estimators=133;, score=-0.653 total time=  15.7s
# Best Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': 59, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 651}
# Best score found:  0.6490164448703422
# Best estimator: RandomForestClassifier(bootstrap=False, max_depth=59, min_samples_split=3,
#                        n_estimators=651, random_state=42)
# Execution time: 1 hours, 16 minutes, 8 seconds

# %% [raw]
# Best Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': 59, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 651}
# Best score found:  0.6490164448703422
# Best estimator: RandomForestClassifier(bootstrap=False, max_depth=59, min_samples_split=3,
#                        n_estimators=651, random_state=42)
# Execution time: 1 hours, 16 minutes, 8 seconds

# %%
# Save Randomized and 5CV results 
RF_nofeat_CV = pd.DataFrame(rf_random.cv_results_)
RF_nofeat_CV.to_csv('RF_nofeat_CV.csv', index=False)
box_fig = pd.read_csv('RF_nofeat_CV.csv')

# %%
# Boxplot MAE Scores for each fold
plt.figure(figsize=(8, 6))
numeric_cols = ['split0_test_score', 'split1_test_score', 'split2_test_score', 'split3_test_score', 'split4_test_score']
box_fig[numeric_cols] = box_fig[numeric_cols].abs()
bp = box_fig.boxplot(column=numeric_cols, patch_artist=True, color='#1f77b4',medianprops=dict(color='green'))
plt.xlabel('Fold')
plt.ylabel('MAE Score')
plt.title('Random Forests MAE Scores for Each Cross Validation Fold')
plt.xticks(ticks=range(1, 6), labels=[f'Fold {i+1}' for i in range(5)])
plt.grid(True)
plt.tight_layout()
plt.savefig('MAE_perFold.png', dpi=300, bbox_inches='tight')  # Save as PNG
plt.show()

# %%
# Plot MAE scores average per cross validation
cv_scores = -box_fig['mean_test_score']
plt.plot(range(1, len(cv_scores) + 1), cv_scores, '-o', label='Average MAE across folds per iteration', color='#1f77b4')

plt.xlabel('Numbers of iterations', fontsize=14, labelpad=10)
plt.ylabel('MAE', fontsize=14, labelpad=10)
plt.title('Random Forests 5-Fold Cross Validation MAE per Iteration', fontsize=16, pad=20)
plt.grid(True, linestyle='--', linewidth=0.5, alpha=0.5)
plt.tick_params(axis='both', which='major', labelsize=12)
plt.ylim(0.5, 0.8)
plt.legend(fontsize=12)
plt.tight_layout()
plt.savefig('AVG_Iterations.png', dpi=300, bbox_inches='tight')  # Save as PNG
plt.show()

# %%
# Trained Random Forests predict test data with best estimator
best_estimator = rf_random.best_estimator_
y_pred = best_estimator.predict(X_test)

# %%
# Evaluation trained best estimator Random Forests
rf_mae = mean_absolute_error(y_test, y_pred)
print(f'Test MAE: {rf_mae:.3f}')
rf_mse = mean_squared_error(y_test, y_pred)
rf_rmse = rf_mse ** 0.5
print(f'Test RMSE: {rf_rmse:.3f}')
rf_kappa = cohen_kappa_score(y_test, y_pred, weights='quadratic')
print(f'Test CWK: {rf_kappa:.3f}')

# Confusion matrix
class_labels = {1: 'challenging', 2: 'moderate', 3: 'user-friendly'}
conf_matrix = confusion_matrix(y_test, y_pred)
conf_matrix_percent = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]
plt.figure(figsize=(8, 6))
plt.imshow(conf_matrix_percent, cmap=plt.cm.Blues, vmin=0, vmax=1)
plt.title('Confusion Matrix Random Forests')
plt.colorbar(label='Percentage')
for i in range(conf_matrix.shape[0]):
    for j in range(conf_matrix.shape[1]):
        plt.text(j, i, f'{conf_matrix_percent[i, j]:.2f}', ha='center', va='center', color='black')

plt.xlabel('Predicted class')
plt.ylabel('True class')
plt.xticks(np.arange(len(class_labels)), [class_labels[i] for i in sorted(class_labels)], rotation=45)
plt.yticks(np.arange(len(class_labels)), [class_labels[i] for i in sorted(class_labels)])

plt.savefig('RFConfusionMatrix.png', dpi=300, bbox_inches='tight')  # Save as PNG
plt.tight_layout()
plt.show()
# Out:
# Test MAE: 0.633
# Test RMSE: 0.988
# Test CWK: 0.306

# %%
# Feature importance Random Forests
feature_importance = best_estimator.feature_importances_
feature_names = X_train.columns
feature_importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': feature_importance})
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# Top 30
n = 30
plt.figure(figsize=(15, 15))
plt.barh(range(n), feature_importance_df['Importance'].head(n), align='center', color='#1f77b4')
plt.yticks(range(n), feature_importance_df['Feature'].head(n))
plt.xlabel('Feature Importance')
plt.ylabel('Feature')
plt.title('Random Forests Most Important Features')
plt.gca().invert_yaxis()  # Invert y-axis to display features in descending order
plt.savefig('Feature importance.png', dpi=300, bbox_inches='tight')  # Save as PNG
plt.show()

# %% [markdown]
# ## LGBM unigrams, bigrams + polarity score without additional features

# %%
# Hyperparameter tuning Randomized search
start_time = time.time()

param_grid = {
    'objective': ['multiclass'],
    'verbose': [-1],
    'num_class': [3],
    'boosting_type': ['gbdt'],
    'num_leaves': list(range(10, 201)),
    'learning_rate': [i/100 for i in range(1, 51)],
    'feature_fraction': [i/10 for i in range(5, 10)],
    'bagging_fraction': [i/10 for i in range(5, 10)],
    'bagging_freq': list(range(1, 11)),
    'min_data_in_leaf': list(range(5, 31)),
    'lambda_l1': [i/10 for i in range(11)],
    'lambda_l2': [i/10 for i in range(11)],
    'max_depth': list(range(5, 71)),
    'min_gain_to_split': [i/100 for i in range(5, 31)],
}

k_fold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
lgbm_classifier = lgb.LGBMClassifier(random_state=42)
lgbm_random = RandomizedSearchCV(estimator=lgbm_classifier,
                                   param_distributions=param_grid,
                                   n_iter=100,
                                   cv=k_fold,
                                   scoring = 'neg_mean_absolute_error',
                                   random_state=42,
                                   verbose = 3)
lgbm_random.fit(X_train, y_train)



print("Best Parameters:", lgbm_random.best_params_)
print("Best score found: ",-lgbm_random.best_score_)
print ('Best estimator:', lgbm_random.best_estimator_)

end_time = time.time()
elapsed_time = end_time - start_time
hours, remainder = divmod(elapsed_time, 3600)
minutes, seconds = divmod(remainder, 60)
print(f"Execution time: {int(hours)} hours, {int(minutes)} minutes, {int(seconds)} seconds")
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV 1/5] END bagging_fraction=0.6, bagging_freq=5, boosting_type=gbdt, feature_fraction=0.6, lambda_l1=0.7, lambda_l2=0.2, learning_rate=0.38, max_depth=55, min_data_in_leaf=22, min_gain_to_split=0.23, num_class=3, num_leaves=52, objective=multiclass, verbose=-1;, score=-0.685 total time=  20.0s
# [CV 2/5] END bagging_fraction=0.6, bagging_freq=5, boosting_type=gbdt, feature_fraction=0.6, lambda_l1=0.7, lambda_l2=0.2, learning_rate=0.38, max_depth=55, min_data_in_leaf=22, min_gain_to_split=0.23, num_class=3, num_leaves=52, objective=multiclass, verbose=-1;, score=-0.684 total time=  19.4s
# [CV 3/5] END bagging_fraction=0.6, bagging_freq=5, boosting_type=gbdt, feature_fraction=0.6, lambda_l1=0.7, lambda_l2=0.2, learning_rate=0.38, max_depth=55, min_data_in_leaf=22, min_gain_to_split=0.23, num_class=3, num_leaves=52, objective=multiclass, verbose=-1;, score=-0.673 total time=  18.9s
# [CV 4/5] END bagging_fraction=0.6, bagging_freq=5, boosting_type=gbdt, feature_fraction=0.6, lambda_l1=0.7, lambda_l2=0.2, learning_rate=0.38, max_depth=55, min_data_in_leaf=22, min_gain_to_split=0.23, num_class=3, num_leaves=52, objective=multiclass, verbose=-1;, score=-0.671 total time=  20.3s
# [CV 5/5] END bagging_fraction=0.6, bagging_freq=5, boosting_type=gbdt, feature_fraction=0.6, lambda_l1=0.7, lambda_l2=0.2, learning_rate=0.38, max_depth=55, min_data_in_leaf=22, min_gain_to_split=0.23, num_class=3, num_leaves=52, objective=multiclass, verbose=-1;, score=-0.675 total time=  19.7s
# [CV 1/5] END bagging_fraction=0.6, bagging_freq=9, boosting_type=gbdt, feature_fraction=0.9, lambda_l1=0.2, lambda_l2=0.2, learning_rate=0.2, max_depth=67, min_data_in_leaf=29, min_gain_to_split=0.13, num_class=3, num_leaves=57, objective=multiclass, verbose=-1;, score=-0.693 total time=  31.5s
# [CV 2/5] END bagging_fraction=0.6, bagging_freq=9, boosting_type=gbdt, feature_fraction=0.9, lambda_l1=0.2, lambda_l2=0.2, learning_rate=0.2, max_depth=67, min_data_in_leaf=29, min_gain_to_split=0.13, num_class=3, num_leaves=57, objective=multiclass, verbose=-1;, score=-0.660 total time=  31.3s
# [CV 3/5] END bagging_fraction=0.6, bagging_freq=9, boosting_type=gbdt, feature_fraction=0.9, lambda_l1=0.2, lambda_l2=0.2, learning_rate=0.2, max_depth=67, min_data_in_leaf=29, min_gain_to_split=0.13, num_class=3, num_leaves=57, objective=multiclass, verbose=-1;, score=-0.651 total time=  34.5s
# [CV 4/5] END bagging_fraction=0.6, bagging_freq=9, boosting_type=gbdt, feature_fraction=0.9, lambda_l1=0.2, lambda_l2=0.2, learning_rate=0.2, max_depth=67, min_data_in_leaf=29, min_gain_to_split=0.13, num_class=3, num_leaves=57, objective=multiclass, verbose=-1;, score=-0.642 total time=  31.5s
# [CV 5/5] END bagging_fraction=0.6, bagging_freq=9, boosting_type=gbdt, feature_fraction=0.9, lambda_l1=0.2, lambda_l2=0.2, learning_rate=0.2, max_depth=67, min_data_in_leaf=29, min_gain_to_split=0.13, num_class=3, num_leaves=57, objective=multiclass, verbose=-1;, score=-0.671 total time=  31.4s
# [CV 1/5] END bagging_fraction=0.7, bagging_freq=8, boosting_type=gbdt, feature_fraction=0.6, lambda_l1=0.5, lambda_l2=0.4, learning_rate=0.37, max_depth=59, min_data_in_leaf=19, min_gain_to_split=0.28, num_class=3, num_leaves=174, objective=multiclass, verbose=-1;, score=-0.688 total time=  23.2s
# [CV 2/5] END bagging_fraction=0.7, bagging_freq=8, boosting_type=gbdt, feature_fraction=0.6, lambda_l1=0.5, lambda_l2=0.4, learning_rate=0.37, max_depth=59, min_data_in_leaf=19, min_gain_to_split=0.28, num_class=3, num_leaves=174, objective=multiclass, verbose=-1;, score=-0.676 total time=  21.0s
# [CV 3/5] END bagging_fraction=0.7, bagging_freq=8, boosting_type=gbdt, feature_fraction=0.6, lambda_l1=0.5, lambda_l2=0.4, learning_rate=0.37, max_depth=59, min_data_in_leaf=19, min_gain_to_split=0.28, num_class=3, num_leaves=174, objective=multiclass, verbose=-1;, score=-0.657 total time=  22.1s
# [CV 4/5] END bagging_fraction=0.7, bagging_freq=8, boosting_type=gbdt, feature_fraction=0.6, lambda_l1=0.5, lambda_l2=0.4, learning_rate=0.37, max_depth=59, min_data_in_leaf=19, min_gain_to_split=0.28, num_class=3, num_leaves=174, objective=multiclass, verbose=-1;, score=-0.671 total time=  21.0s
# [CV 5/5] END bagging_fraction=0.7, bagging_freq=8, boosting_type=gbdt, feature_fraction=0.6, lambda_l1=0.5, lambda_l2=0.4, learning_rate=0.37, max_depth=59, min_data_in_leaf=19, min_gain_to_split=0.28, num_class=3, num_leaves=174, objective=multiclass, verbose=-1;, score=-0.699 total time=  21.9s
# [CV 1/5] END bagging_fraction=0.5, bagging_freq=8, boosting_type=gbdt, feature_fraction=0.8, lambda_l1=0.9, lambda_l2=0.1, learning_rate=0.18, max_depth=22, min_data_in_leaf=23, min_gain_to_split=0.15, num_class=3, num_leaves=138, objective=multiclass, verbose=-1;, score=-0.672 total time=  18.3s
# [CV 2/5] END bagging_fraction=0.5, bagging_freq=8, boosting_type=gbdt, feature_fraction=0.8, lambda_l1=0.9, lambda_l2=0.1, learning_rate=0.18, max_depth=22, min_data_in_leaf=23, min_gain_to_split=0.15, num_class=3, num_leaves=138, objective=multiclass, verbose=-1;, score=-0.665 total time=  17.9s
# [CV 3/5] END bagging_fraction=0.5, bagging_freq=8, boosting_type=gbdt, feature_fraction=0.8, lambda_l1=0.9, lambda_l2=0.1, learning_rate=0.18, max_depth=22, min_data_in_leaf=23, min_gain_to_split=0.15, num_class=3, num_leaves=138, objective=multiclass, verbose=-1;, score=-0.648 total time=  18.1s
# [CV 4/5] END bagging_fraction=0.5, bagging_freq=8, boosting_type=gbdt, feature_fraction=0.8, lambda_l1=0.9, lambda_l2=0.1, learning_rate=0.18, max_depth=22, min_data_in_leaf=23, min_gain_to_split=0.15, num_class=3, num_leaves=138, objective=multiclass, verbose=-1;, score=-0.652 total time=  20.9s
# [CV 5/5] END bagging_fraction=0.5, bagging_freq=8, boosting_type=gbdt, feature_fraction=0.8, lambda_l1=0.9, lambda_l2=0.1, learning_rate=0.18, max_depth=22, min_data_in_leaf=23, min_gain_to_split=0.15, num_class=3, num_leaves=138, objective=multiclass, verbose=-1;, score=-0.660 total time=  18.0s
# [CV 1/5] END bagging_fraction=0.5, bagging_freq=6, boosting_type=gbdt, feature_fraction=0.7, lambda_l1=0.5, lambda_l2=0.9, learning_rate=0.04, max_depth=38, min_data_in_leaf=11, min_gain_to_split=0.27, num_class=3, num_leaves=50, objective=multiclass, verbose=-1;, score=-0.643 total time=  22.7s
# [CV 2/5] END bagging_fraction=0.5, bagging_freq=6, boosting_type=gbdt, feature_fraction=0.7, lambda_l1=0.5, lambda_l2=0.9, learning_rate=0.04, max_depth=38, min_data_in_leaf=11, min_gain_to_split=0.27, num_class=3, num_leaves=50, objective=multiclass, verbose=-1;, score=-0.642 total time=  23.7s
# [CV 3/5] END bagging_fraction=0.5, bagging_freq=6, boosting_type=gbdt, feature_fraction=0.7, lambda_l1=0.5, lambda_l2=0.9, learning_rate=0.04, max_depth=38, min_data_in_leaf=11, min_gain_to_split=0.27, num_class=3, num_leaves=50, objective=multiclass, verbose=-1;, score=-0.620 total time=  22.9s
# [CV 4/5] END bagging_fraction=0.5, bagging_freq=6, boosting_type=gbdt, feature_fraction=0.7, lambda_l1=0.5, lambda_l2=0.9, learning_rate=0.04, max_depth=38, min_data_in_leaf=11, min_gain_to_split=0.27, num_class=3, num_leaves=50, objective=multiclass, verbose=-1;, score=-0.640 total time=  22.9s
# [CV 5/5] END bagging_fraction=0.5, bagging_freq=6, boosting_type=gbdt, feature_fraction=0.7, lambda_l1=0.5, lambda_l2=0.9, learning_rate=0.04, max_depth=38, min_data_in_leaf=11, min_gain_to_split=0.27, num_class=3, num_leaves=50, objective=multiclass, verbose=-1;, score=-0.654 total time=  23.4s
# [CV 1/5] END bagging_fraction=0.8, bagging_freq=6, boosting_type=gbdt, feature_fraction=0.7, lambda_l1=0.9, lambda_l2=0.8, learning_rate=0.22, max_depth=30, min_data_in_leaf=20, min_gain_to_split=0.05, num_class=3, num_leaves=176, objective=multiclass, verbose=-1;, score=-0.669 total time=  27.0s
# [CV 2/5] END bagging_fraction=0.8, bagging_freq=6, boosting_type=gbdt, feature_fraction=0.7, lambda_l1=0.9, lambda_l2=0.8, learning_rate=0.22, max_depth=30, min_data_in_leaf=20, min_gain_to_split=0.05, num_class=3, num_leaves=176, objective=multiclass, verbose=-1;, score=-0.658 total time=  27.3s
# [CV 3/5] END bagging_fraction=0.8, bagging_freq=6, boosting_type=gbdt, feature_fraction=0.7, lambda_l1=0.9, lambda_l2=0.8, learning_rate=0.22, max_depth=30, min_data_in_leaf=20, min_gain_to_split=0.05, num_class=3, num_leaves=176, objective=multiclass, verbose=-1;, score=-0.631 total time=  28.1s
# [CV 4/5] END bagging_fraction=0.8, bagging_freq=6, boosting_type=gbdt, feature_fraction=0.7, lambda_l1=0.9, lambda_l2=0.8, learning_rate=0.22, max_depth=30, min_data_in_leaf=20, min_gain_to_split=0.05, num_class=3, num_leaves=176, objective=multiclass, verbose=-1;, score=-0.648 total time=  27.7s
# [CV 5/5] END bagging_fraction=0.8, bagging_freq=6, boosting_type=gbdt, feature_fraction=0.7, lambda_l1=0.9, lambda_l2=0.8, learning_rate=0.22, max_depth=30, min_data_in_leaf=20, min_gain_to_split=0.05, num_class=3, num_leaves=176, objective=multiclass, verbose=-1;, score=-0.665 total time=  29.3s
# [CV 1/5] END bagging_fraction=0.7, bagging_freq=9, boosting_type=gbdt, feature_fraction=0.5, lambda_l1=0.4, lambda_l2=0.1, learning_rate=0.29, max_depth=60, min_data_in_leaf=27, min_gain_to_split=0.29, num_class=3, num_leaves=62, objective=multiclass, verbose=-1;, score=-0.688 total time=  19.8s
# [CV 2/5] END bagging_fraction=0.7, bagging_freq=9, boosting_type=gbdt, feature_fraction=0.5, lambda_l1=0.4, lambda_l2=0.1, learning_rate=0.29, max_depth=60, min_data_in_leaf=27, min_gain_to_split=0.29, num_class=3, num_leaves=62, objective=multiclass, verbose=-1;, score=-0.679 total time=  20.3s
# [CV 3/5] END bagging_fraction=0.7, bagging_freq=9, boosting_type=gbdt, feature_fraction=0.5, lambda_l1=0.4, lambda_l2=0.1, learning_rate=0.29, max_depth=60, min_data_in_leaf=27, min_gain_to_split=0.29, num_class=3, num_leaves=62, objective=multiclass, verbose=-1;, score=-0.649 total time=  20.4s
# [CV 4/5] END bagging_fraction=0.7, bagging_freq=9, boosting_type=gbdt, feature_fraction=0.5, lambda_l1=0.4, lambda_l2=0.1, learning_rate=0.29, max_depth=60, min_data_in_leaf=27, min_gain_to_split=0.29, num_class=3, num_leaves=62, objective=multiclass, verbose=-1;, score=-0.648 total time=  19.7s
# [CV 5/5] END bagging_fraction=0.7, bagging_freq=9, boosting_type=gbdt, feature_fraction=0.5, lambda_l1=0.4, lambda_l2=0.1, learning_rate=0.29, max_depth=60, min_data_in_leaf=27, min_gain_to_split=0.29, num_class=3, num_leaves=62, objective=multiclass, verbose=-1;, score=-0.674 total time=  20.5s
# [CV 1/5] END bagging_fraction=0.6, bagging_freq=3, boosting_type=gbdt, feature_fraction=0.9, lambda_l1=0.1, lambda_l2=0.3, learning_rate=0.45, max_depth=47, min_data_in_leaf=19, min_gain_to_split=0.26, num_class=3, num_leaves=74, objective=multiclass, verbose=-1;, score=-0.708 total time=  27.4s
# [CV 2/5] END bagging_fraction=0.6, bagging_freq=3, boosting_type=gbdt, feature_fraction=0.9, lambda_l1=0.1, lambda_l2=0.3, learning_rate=0.45, max_depth=47, min_data_in_leaf=19, min_gain_to_split=0.26, num_class=3, num_leaves=74, objective=multiclass, verbose=-1;, score=-0.681 total time=  27.9s
# [CV 3/5] END bagging_fraction=0.6, bagging_freq=3, boosting_type=gbdt, feature_fraction=0.9, lambda_l1=0.1, lambda_l2=0.3, learning_rate=0.45, max_depth=47, min_data_in_leaf=19, min_gain_to_split=0.26, num_class=3, num_leaves=74, objective=multiclass, verbose=-1;, score=-0.658 total time=  28.3s
# [CV 4/5] END bagging_fraction=0.6, bagging_freq=3, boosting_type=gbdt, feature_fraction=0.9, lambda_l1=0.1, lambda_l2=0.3, learning_rate=0.45, max_depth=47, min_data_in_leaf=19, min_gain_to_split=0.26, num_class=3, num_leaves=74, objective=multiclass, verbose=-1;, score=-0.671 total time=  28.4s
# [CV 5/5] END bagging_fraction=0.6, bagging_freq=3, boosting_type=gbdt, feature_fraction=0.9, lambda_l1=0.1, lambda_l2=0.3, learning_rate=0.45, max_depth=47, min_data_in_leaf=19, min_gain_to_split=0.26, num_class=3, num_leaves=74, objective=multiclass, verbose=-1;, score=-0.686 total time=  28.2s
# [CV 1/5] END bagging_fraction=0.7, bagging_freq=6, boosting_type=gbdt, feature_fraction=0.6, lambda_l1=0.3, lambda_l2=0.1, learning_rate=0.43, max_depth=31, min_data_in_leaf=16, min_gain_to_split=0.12, num_class=3, num_leaves=132, objective=multiclass, verbose=-1;, score=-0.692 total time=  25.5s
# [CV 2/5] END bagging_fraction=0.7, bagging_freq=6, boosting_type=gbdt, feature_fraction=0.6, lambda_l1=0.3, lambda_l2=0.1, learning_rate=0.43, max_depth=31, min_data_in_leaf=16, min_gain_to_split=0.12, num_class=3, num_leaves=132, objective=multiclass, verbose=-1;, score=-0.697 total time=  24.5s
# [CV 3/5] END bagging_fraction=0.7, bagging_freq=6, boosting_type=gbdt, feature_fraction=0.6, lambda_l1=0.3, lambda_l2=0.1, learning_rate=0.43, max_depth=31, min_data_in_leaf=16, min_gain_to_split=0.12, num_class=3, num_leaves=132, objective=multiclass, verbose=-1;, score=-0.664 total time=  24.8s
# [CV 4/5] END bagging_fraction=0.7, bagging_freq=6, boosting_type=gbdt, feature_fraction=0.6, lambda_l1=0.3, lambda_l2=0.1, learning_rate=0.43, max_depth=31, min_data_in_leaf=16, min_gain_to_split=0.12, num_class=3, num_leaves=132, objective=multiclass, verbose=-1;, score=-0.660 total time=  23.9s
# [CV 5/5] END bagging_fraction=0.7, bagging_freq=6, boosting_type=gbdt, feature_fraction=0.6, lambda_l1=0.3, lambda_l2=0.1, learning_rate=0.43, max_depth=31, min_data_in_leaf=16, min_gain_to_split=0.12, num_class=3, num_leaves=132, objective=multiclass, verbose=-1;, score=-0.705 total time=  24.5s
# [CV 1/5] END bagging_fraction=0.9, bagging_freq=8, boosting_type=gbdt, feature_fraction=0.7, lambda_l1=0.7, lambda_l2=0.4, learning_rate=0.31, max_depth=6, min_data_in_leaf=24, min_gain_to_split=0.29, num_class=3, num_leaves=133, objective=multiclass, verbose=-1;, score=-0.659 total time=   7.3s
# [CV 2/5] END bagging_fraction=0.9, bagging_freq=8, boosting_type=gbdt, feature_fraction=0.7, lambda_l1=0.7, lambda_l2=0.4, learning_rate=0.31, max_depth=6, min_data_in_leaf=24, min_gain_to_split=0.29, num_class=3, num_leaves=133, objective=multiclass, verbose=-1;, score=-0.651 total time=   7.0s
# [CV 3/5] END bagging_fraction=0.9, bagging_freq=8, boosting_type=gbdt, feature_fraction=0.7, lambda_l1=0.7, lambda_l2=0.4, learning_rate=0.31, max_depth=6, min_data_in_leaf=24, min_gain_to_split=0.29, num_class=3, num_leaves=133, objective=multiclass, verbose=-1;, score=-0.614 total time=   7.2s
# [CV 4/5] END bagging_fraction=0.9, bagging_freq=8, boosting_type=gbdt, feature_fraction=0.7, lambda_l1=0.7, lambda_l2=0.4, learning_rate=0.31, max_depth=6, min_data_in_leaf=24, min_gain_to_split=0.29, num_class=3, num_leaves=133, objective=multiclass, verbose=-1;, score=-0.626 total time=   7.2s
# [CV 5/5] END bagging_fraction=0.9, bagging_freq=8, boosting_type=gbdt, feature_fraction=0.7, lambda_l1=0.7, lambda_l2=0.4, learning_rate=0.31, max_depth=6, min_data_in_leaf=24, min_gain_to_split=0.29, num_class=3, num_leaves=133, objective=multiclass, verbose=-1;, score=-0.646 total time=   6.8s
# [CV 1/5] END bagging_fraction=0.7, bagging_freq=1, boosting_type=gbdt, feature_fraction=0.6, lambda_l1=0.3, lambda_l2=0.3, learning_rate=0.18, max_depth=43, min_data_in_leaf=30, min_gain_to_split=0.18, num_class=3, num_leaves=76, objective=multiclass, verbose=-1;, score=-0.660 total time=  25.2s
# [CV 2/5] END bagging_fraction=0.7, bagging_freq=1, boosting_type=gbdt, feature_fraction=0.6, lambda_l1=0.3, lambda_l2=0.3, learning_rate=0.18, max_depth=43, min_data_in_leaf=30, min_gain_to_split=0.18, num_class=3, num_leaves=76, objective=multiclass, verbose=-1;, score=-0.659 total time=  25.5s
# [CV 3/5] END bagging_fraction=0.7, bagging_freq=1, boosting_type=gbdt, feature_fraction=0.6, lambda_l1=0.3, lambda_l2=0.3, learning_rate=0.18, max_depth=43, min_data_in_leaf=30, min_gain_to_split=0.18, num_class=3, num_leaves=76, objective=multiclass, verbose=-1;, score=-0.642 total time=  25.1s
# [CV 4/5] END bagging_fraction=0.7, bagging_freq=1, boosting_type=gbdt, feature_fraction=0.6, lambda_l1=0.3, lambda_l2=0.3, learning_rate=0.18, max_depth=43, min_data_in_leaf=30, min_gain_to_split=0.18, num_class=3, num_leaves=76, objective=multiclass, verbose=-1;, score=-0.656 total time=  24.8s
# [CV 5/5] END bagging_fraction=0.7, bagging_freq=1, boosting_type=gbdt, feature_fraction=0.6, lambda_l1=0.3, lambda_l2=0.3, learning_rate=0.18, max_depth=43, min_data_in_leaf=30, min_gain_to_split=0.18, num_class=3, num_leaves=76, objective=multiclass, verbose=-1;, score=-0.661 total time=  25.6s
# [CV 1/5] END bagging_fraction=0.8, bagging_freq=9, boosting_type=gbdt, feature_fraction=0.8, lambda_l1=0.7, lambda_l2=0.2, learning_rate=0.22, max_depth=43, min_data_in_leaf=10, min_gain_to_split=0.21, num_class=3, num_leaves=124, objective=multiclass, verbose=-1;, score=-0.690 total time=  31.3s
# [CV 2/5] END bagging_fraction=0.8, bagging_freq=9, boosting_type=gbdt, feature_fraction=0.8, lambda_l1=0.7, lambda_l2=0.2, learning_rate=0.22, max_depth=43, min_data_in_leaf=10, min_gain_to_split=0.21, num_class=3, num_leaves=124, objective=multiclass, verbose=-1;, score=-0.657 total time=  29.0s
# [CV 3/5] END bagging_fraction=0.8, bagging_freq=9, boosting_type=gbdt, feature_fraction=0.8, lambda_l1=0.7, lambda_l2=0.2, learning_rate=0.22, max_depth=43, min_data_in_leaf=10, min_gain_to_split=0.21, num_class=3, num_leaves=124, objective=multiclass, verbose=-1;, score=-0.645 total time=  28.8s
# [CV 4/5] END bagging_fraction=0.8, bagging_freq=9, boosting_type=gbdt, feature_fraction=0.8, lambda_l1=0.7, lambda_l2=0.2, learning_rate=0.22, max_depth=43, min_data_in_leaf=10, min_gain_to_split=0.21, num_class=3, num_leaves=124, objective=multiclass, verbose=-1;, score=-0.640 total time=  28.7s
# [CV 5/5] END bagging_fraction=0.8, bagging_freq=9, boosting_type=gbdt, feature_fraction=0.8, lambda_l1=0.7, lambda_l2=0.2, learning_rate=0.22, max_depth=43, min_data_in_leaf=10, min_gain_to_split=0.21, num_class=3, num_leaves=124, objective=multiclass, verbose=-1;, score=-0.673 total time=  28.6s
# [CV 1/5] END bagging_fraction=0.5, bagging_freq=8, boosting_type=gbdt, feature_fraction=0.8, lambda_l1=0.3, lambda_l2=0.1, learning_rate=0.48, max_depth=12, min_data_in_leaf=18, min_gain_to_split=0.22, num_class=3, num_leaves=154, objective=multiclass, verbose=-1;, score=-0.698 total time=  11.4s
# [CV 2/5] END bagging_fraction=0.5, bagging_freq=8, boosting_type=gbdt, feature_fraction=0.8, lambda_l1=0.3, lambda_l2=0.1, learning_rate=0.48, max_depth=12, min_data_in_leaf=18, min_gain_to_split=0.22, num_class=3, num_leaves=154, objective=multiclass, verbose=-1;, score=-0.677 total time=  11.8s
# [CV 3/5] END bagging_fraction=0.5, bagging_freq=8, boosting_type=gbdt, feature_fraction=0.8, lambda_l1=0.3, lambda_l2=0.1, learning_rate=0.48, max_depth=12, min_data_in_leaf=18, min_gain_to_split=0.22, num_class=3, num_leaves=154, objective=multiclass, verbose=-1;, score=-0.674 total time=  11.8s
# [CV 4/5] END bagging_fraction=0.5, bagging_freq=8, boosting_type=gbdt, feature_fraction=0.8, lambda_l1=0.3, lambda_l2=0.1, learning_rate=0.48, max_depth=12, min_data_in_leaf=18, min_gain_to_split=0.22, num_class=3, num_leaves=154, objective=multiclass, verbose=-1;, score=-0.675 total time=  11.2s
# [CV 5/5] END bagging_fraction=0.5, bagging_freq=8, boosting_type=gbdt, feature_fraction=0.8, lambda_l1=0.3, lambda_l2=0.1, learning_rate=0.48, max_depth=12, min_data_in_leaf=18, min_gain_to_split=0.22, num_class=3, num_leaves=154, objective=multiclass, verbose=-1;, score=-0.687 total time=  11.0s
# [CV 1/5] END bagging_fraction=0.5, bagging_freq=1, boosting_type=gbdt, feature_fraction=0.6, lambda_l1=0.8, lambda_l2=0.2, learning_rate=0.38, max_depth=50, min_data_in_leaf=21, min_gain_to_split=0.1, num_class=3, num_leaves=87, objective=multiclass, verbose=-1;, score=-0.694 total time=  26.1s
# [CV 2/5] END bagging_fraction=0.5, bagging_freq=1, boosting_type=gbdt, feature_fraction=0.6, lambda_l1=0.8, lambda_l2=0.2, learning_rate=0.38, max_depth=50, min_data_in_leaf=21, min_gain_to_split=0.1, num_class=3, num_leaves=87, objective=multiclass, verbose=-1;, score=-0.690 total time=  25.8s
# [CV 3/5] END bagging_fraction=0.5, bagging_freq=1, boosting_type=gbdt, feature_fraction=0.6, lambda_l1=0.8, lambda_l2=0.2, learning_rate=0.38, max_depth=50, min_data_in_leaf=21, min_gain_to_split=0.1, num_class=3, num_leaves=87, objective=multiclass, verbose=-1;, score=-0.679 total time=  25.1s
# [CV 4/5] END bagging_fraction=0.5, bagging_freq=1, boosting_type=gbdt, feature_fraction=0.6, lambda_l1=0.8, lambda_l2=0.2, learning_rate=0.38, max_depth=50, min_data_in_leaf=21, min_gain_to_split=0.1, num_class=3, num_leaves=87, objective=multiclass, verbose=-1;, score=-0.683 total time=  27.2s
# [CV 5/5] END bagging_fraction=0.5, bagging_freq=1, boosting_type=gbdt, feature_fraction=0.6, lambda_l1=0.8, lambda_l2=0.2, learning_rate=0.38, max_depth=50, min_data_in_leaf=21, min_gain_to_split=0.1, num_class=3, num_leaves=87, objective=multiclass, verbose=-1;, score=-0.697 total time=  25.9s
# [CV 1/5] END bagging_fraction=0.6, bagging_freq=3, boosting_type=gbdt, feature_fraction=0.7, lambda_l1=0.2, lambda_l2=0.6, learning_rate=0.05, max_depth=20, min_data_in_leaf=28, min_gain_to_split=0.09, num_class=3, num_leaves=152, objective=multiclass, verbose=-1;, score=-0.638 total time=  20.0s
# [CV 2/5] END bagging_fraction=0.6, bagging_freq=3, boosting_type=gbdt, feature_fraction=0.7, lambda_l1=0.2, lambda_l2=0.6, learning_rate=0.05, max_depth=20, min_data_in_leaf=28, min_gain_to_split=0.09, num_class=3, num_leaves=152, objective=multiclass, verbose=-1;, score=-0.640 total time=  21.3s
# [CV 3/5] END bagging_fraction=0.6, bagging_freq=3, boosting_type=gbdt, feature_fraction=0.7, lambda_l1=0.2, lambda_l2=0.6, learning_rate=0.05, max_depth=20, min_data_in_leaf=28, min_gain_to_split=0.09, num_class=3, num_leaves=152, objective=multiclass, verbose=-1;, score=-0.617 total time=  20.0s
# [CV 4/5] END bagging_fraction=0.6, bagging_freq=3, boosting_type=gbdt, feature_fraction=0.7, lambda_l1=0.2, lambda_l2=0.6, learning_rate=0.05, max_depth=20, min_data_in_leaf=28, min_gain_to_split=0.09, num_class=3, num_leaves=152, objective=multiclass, verbose=-1;, score=-0.647 total time=  20.3s
# [CV 5/5] END bagging_fraction=0.6, bagging_freq=3, boosting_type=gbdt, feature_fraction=0.7, lambda_l1=0.2, lambda_l2=0.6, learning_rate=0.05, max_depth=20, min_data_in_leaf=28, min_gain_to_split=0.09, num_class=3, num_leaves=152, objective=multiclass, verbose=-1;, score=-0.650 total time=  21.3s
# [CV 1/5] END bagging_fraction=0.6, bagging_freq=9, boosting_type=gbdt, feature_fraction=0.5, lambda_l1=0.1, lambda_l2=0.9, learning_rate=0.37, max_depth=19, min_data_in_leaf=18, min_gain_to_split=0.27, num_class=3, num_leaves=104, objective=multiclass, verbose=-1;, score=-0.694 total time=  15.0s
# [CV 2/5] END bagging_fraction=0.6, bagging_freq=9, boosting_type=gbdt, feature_fraction=0.5, lambda_l1=0.1, lambda_l2=0.9, learning_rate=0.37, max_depth=19, min_data_in_leaf=18, min_gain_to_split=0.27, num_class=3, num_leaves=104, objective=multiclass, verbose=-1;, score=-0.676 total time=  14.9s
# [CV 3/5] END bagging_fraction=0.6, bagging_freq=9, boosting_type=gbdt, feature_fraction=0.5, lambda_l1=0.1, lambda_l2=0.9, learning_rate=0.37, max_depth=19, min_data_in_leaf=18, min_gain_to_split=0.27, num_class=3, num_leaves=104, objective=multiclass, verbose=-1;, score=-0.662 total time=  14.9s
# [CV 4/5] END bagging_fraction=0.6, bagging_freq=9, boosting_type=gbdt, feature_fraction=0.5, lambda_l1=0.1, lambda_l2=0.9, learning_rate=0.37, max_depth=19, min_data_in_leaf=18, min_gain_to_split=0.27, num_class=3, num_leaves=104, objective=multiclass, verbose=-1;, score=-0.653 total time=  15.0s
# [CV 5/5] END bagging_fraction=0.6, bagging_freq=9, boosting_type=gbdt, feature_fraction=0.5, lambda_l1=0.1, lambda_l2=0.9, learning_rate=0.37, max_depth=19, min_data_in_leaf=18, min_gain_to_split=0.27, num_class=3, num_leaves=104, objective=multiclass, verbose=-1;, score=-0.670 total time=  15.0s
# [CV 1/5] END bagging_fraction=0.6, bagging_freq=7, boosting_type=gbdt, feature_fraction=0.6, lambda_l1=0.2, lambda_l2=0.7, learning_rate=0.24, max_depth=27, min_data_in_leaf=24, min_gain_to_split=0.14, num_class=3, num_leaves=191, objective=multiclass, verbose=-1;, score=-0.685 total time=  20.9s
# [CV 2/5] END bagging_fraction=0.6, bagging_freq=7, boosting_type=gbdt, feature_fraction=0.6, lambda_l1=0.2, lambda_l2=0.7, learning_rate=0.24, max_depth=27, min_data_in_leaf=24, min_gain_to_split=0.14, num_class=3, num_leaves=191, objective=multiclass, verbose=-1;, score=-0.664 total time=  22.2s
# [CV 3/5] END bagging_fraction=0.6, bagging_freq=7, boosting_type=gbdt, feature_fraction=0.6, lambda_l1=0.2, lambda_l2=0.7, learning_rate=0.24, max_depth=27, min_data_in_leaf=24, min_gain_to_split=0.14, num_class=3, num_leaves=191, objective=multiclass, verbose=-1;, score=-0.659 total time=  22.3s
# [CV 4/5] END bagging_fraction=0.6, bagging_freq=7, boosting_type=gbdt, feature_fraction=0.6, lambda_l1=0.2, lambda_l2=0.7, learning_rate=0.24, max_depth=27, min_data_in_leaf=24, min_gain_to_split=0.14, num_class=3, num_leaves=191, objective=multiclass, verbose=-1;, score=-0.651 total time=  22.1s
# [CV 5/5] END bagging_fraction=0.6, bagging_freq=7, boosting_type=gbdt, feature_fraction=0.6, lambda_l1=0.2, lambda_l2=0.7, learning_rate=0.24, max_depth=27, min_data_in_leaf=24, min_gain_to_split=0.14, num_class=3, num_leaves=191, objective=multiclass, verbose=-1;, score=-0.669 total time=  20.8s
# [CV 1/5] END bagging_fraction=0.5, bagging_freq=4, boosting_type=gbdt, feature_fraction=0.5, lambda_l1=0.8, lambda_l2=0.3, learning_rate=0.03, max_depth=60, min_data_in_leaf=6, min_gain_to_split=0.26, num_class=3, num_leaves=162, objective=multiclass, verbose=-1;, score=-0.646 total time=  35.9s
# [CV 2/5] END bagging_fraction=0.5, bagging_freq=4, boosting_type=gbdt, feature_fraction=0.5, lambda_l1=0.8, lambda_l2=0.3, learning_rate=0.03, max_depth=60, min_data_in_leaf=6, min_gain_to_split=0.26, num_class=3, num_leaves=162, objective=multiclass, verbose=-1;, score=-0.638 total time=  36.0s
# [CV 3/5] END bagging_fraction=0.5, bagging_freq=4, boosting_type=gbdt, feature_fraction=0.5, lambda_l1=0.8, lambda_l2=0.3, learning_rate=0.03, max_depth=60, min_data_in_leaf=6, min_gain_to_split=0.26, num_class=3, num_leaves=162, objective=multiclass, verbose=-1;, score=-0.620 total time=  35.3s
# [CV 4/5] END bagging_fraction=0.5, bagging_freq=4, boosting_type=gbdt, feature_fraction=0.5, lambda_l1=0.8, lambda_l2=0.3, learning_rate=0.03, max_depth=60, min_data_in_leaf=6, min_gain_to_split=0.26, num_class=3, num_leaves=162, objective=multiclass, verbose=-1;, score=-0.641 total time=  36.6s
# [CV 5/5] END bagging_fraction=0.5, bagging_freq=4, boosting_type=gbdt, feature_fraction=0.5, lambda_l1=0.8, lambda_l2=0.3, learning_rate=0.03, max_depth=60, min_data_in_leaf=6, min_gain_to_split=0.26, num_class=3, num_leaves=162, objective=multiclass, verbose=-1;, score=-0.656 total time=  35.5s
# [CV 1/5] END bagging_fraction=0.9, bagging_freq=6, boosting_type=gbdt, feature_fraction=0.7, lambda_l1=0.8, lambda_l2=1.0, learning_rate=0.15, max_depth=42, min_data_in_leaf=19, min_gain_to_split=0.2, num_class=3, num_leaves=118, objective=multiclass, verbose=-1;, score=-0.664 total time=  29.5s
# [CV 2/5] END bagging_fraction=0.9, bagging_freq=6, boosting_type=gbdt, feature_fraction=0.7, lambda_l1=0.8, lambda_l2=1.0, learning_rate=0.15, max_depth=42, min_data_in_leaf=19, min_gain_to_split=0.2, num_class=3, num_leaves=118, objective=multiclass, verbose=-1;, score=-0.654 total time=  30.8s
# [CV 3/5] END bagging_fraction=0.9, bagging_freq=6, boosting_type=gbdt, feature_fraction=0.7, lambda_l1=0.8, lambda_l2=1.0, learning_rate=0.15, max_depth=42, min_data_in_leaf=19, min_gain_to_split=0.2, num_class=3, num_leaves=118, objective=multiclass, verbose=-1;, score=-0.635 total time=  29.4s
# [CV 4/5] END bagging_fraction=0.9, bagging_freq=6, boosting_type=gbdt, feature_fraction=0.7, lambda_l1=0.8, lambda_l2=1.0, learning_rate=0.15, max_depth=42, min_data_in_leaf=19, min_gain_to_split=0.2, num_class=3, num_leaves=118, objective=multiclass, verbose=-1;, score=-0.636 total time=  28.9s
# [CV 5/5] END bagging_fraction=0.9, bagging_freq=6, boosting_type=gbdt, feature_fraction=0.7, lambda_l1=0.8, lambda_l2=1.0, learning_rate=0.15, max_depth=42, min_data_in_leaf=19, min_gain_to_split=0.2, num_class=3, num_leaves=118, objective=multiclass, verbose=-1;, score=-0.661 total time=  29.3s
# [CV 1/5] END bagging_fraction=0.5, bagging_freq=10, boosting_type=gbdt, feature_fraction=0.6, lambda_l1=0.9, lambda_l2=0.3, learning_rate=0.45, max_depth=20, min_data_in_leaf=21, min_gain_to_split=0.18, num_class=3, num_leaves=158, objective=multiclass, verbose=-1;, score=-0.710 total time=  14.1s
# [CV 2/5] END bagging_fraction=0.5, bagging_freq=10, boosting_type=gbdt, feature_fraction=0.6, lambda_l1=0.9, lambda_l2=0.3, learning_rate=0.45, max_depth=20, min_data_in_leaf=21, min_gain_to_split=0.18, num_class=3, num_leaves=158, objective=multiclass, verbose=-1;, score=-0.685 total time=  14.3s
# [CV 3/5] END bagging_fraction=0.5, bagging_freq=10, boosting_type=gbdt, feature_fraction=0.6, lambda_l1=0.9, lambda_l2=0.3, learning_rate=0.45, max_depth=20, min_data_in_leaf=21, min_gain_to_split=0.18, num_class=3, num_leaves=158, objective=multiclass, verbose=-1;, score=-0.683 total time=  14.3s
# [CV 4/5] END bagging_fraction=0.5, bagging_freq=10, boosting_type=gbdt, feature_fraction=0.6, lambda_l1=0.9, lambda_l2=0.3, learning_rate=0.45, max_depth=20, min_data_in_leaf=21, min_gain_to_split=0.18, num_class=3, num_leaves=158, objective=multiclass, verbose=-1;, score=-0.677 total time=  14.3s
# [CV 5/5] END bagging_fraction=0.5, bagging_freq=10, boosting_type=gbdt, feature_fraction=0.6, lambda_l1=0.9, lambda_l2=0.3, learning_rate=0.45, max_depth=20, min_data_in_leaf=21, min_gain_to_split=0.18, num_class=3, num_leaves=158, objective=multiclass, verbose=-1;, score=-0.684 total time=  14.2s
# [CV 1/5] END bagging_fraction=0.9, bagging_freq=8, boosting_type=gbdt, feature_fraction=0.9, lambda_l1=0.9, lambda_l2=0.7, learning_rate=0.2, max_depth=8, min_data_in_leaf=6, min_gain_to_split=0.19, num_class=3, num_leaves=126, objective=multiclass, verbose=-1;, score=-0.667 total time=  12.9s
# [CV 2/5] END bagging_fraction=0.9, bagging_freq=8, boosting_type=gbdt, feature_fraction=0.9, lambda_l1=0.9, lambda_l2=0.7, learning_rate=0.2, max_depth=8, min_data_in_leaf=6, min_gain_to_split=0.19, num_class=3, num_leaves=126, objective=multiclass, verbose=-1;, score=-0.648 total time=  12.5s
# [CV 3/5] END bagging_fraction=0.9, bagging_freq=8, boosting_type=gbdt, feature_fraction=0.9, lambda_l1=0.9, lambda_l2=0.7, learning_rate=0.2, max_depth=8, min_data_in_leaf=6, min_gain_to_split=0.19, num_class=3, num_leaves=126, objective=multiclass, verbose=-1;, score=-0.614 total time=  12.3s
# [CV 4/5] END bagging_fraction=0.9, bagging_freq=8, boosting_type=gbdt, feature_fraction=0.9, lambda_l1=0.9, lambda_l2=0.7, learning_rate=0.2, max_depth=8, min_data_in_leaf=6, min_gain_to_split=0.19, num_class=3, num_leaves=126, objective=multiclass, verbose=-1;, score=-0.641 total time=  12.7s
# [CV 5/5] END bagging_fraction=0.9, bagging_freq=8, boosting_type=gbdt, feature_fraction=0.9, lambda_l1=0.9, lambda_l2=0.7, learning_rate=0.2, max_depth=8, min_data_in_leaf=6, min_gain_to_split=0.19, num_class=3, num_leaves=126, objective=multiclass, verbose=-1;, score=-0.653 total time=  13.0s
# [CV 1/5] END bagging_fraction=0.8, bagging_freq=5, boosting_type=gbdt, feature_fraction=0.7, lambda_l1=0.3, lambda_l2=0.5, learning_rate=0.12, max_depth=60, min_data_in_leaf=10, min_gain_to_split=0.22, num_class=3, num_leaves=25, objective=multiclass, verbose=-1;, score=-0.648 total time=  15.9s
# [CV 2/5] END bagging_fraction=0.8, bagging_freq=5, boosting_type=gbdt, feature_fraction=0.7, lambda_l1=0.3, lambda_l2=0.5, learning_rate=0.12, max_depth=60, min_data_in_leaf=10, min_gain_to_split=0.22, num_class=3, num_leaves=25, objective=multiclass, verbose=-1;, score=-0.647 total time=  15.9s
# [CV 3/5] END bagging_fraction=0.8, bagging_freq=5, boosting_type=gbdt, feature_fraction=0.7, lambda_l1=0.3, lambda_l2=0.5, learning_rate=0.12, max_depth=60, min_data_in_leaf=10, min_gain_to_split=0.22, num_class=3, num_leaves=25, objective=multiclass, verbose=-1;, score=-0.616 total time=  17.4s
# [CV 4/5] END bagging_fraction=0.8, bagging_freq=5, boosting_type=gbdt, feature_fraction=0.7, lambda_l1=0.3, lambda_l2=0.5, learning_rate=0.12, max_depth=60, min_data_in_leaf=10, min_gain_to_split=0.22, num_class=3, num_leaves=25, objective=multiclass, verbose=-1;, score=-0.622 total time=  16.0s
# [CV 5/5] END bagging_fraction=0.8, bagging_freq=5, boosting_type=gbdt, feature_fraction=0.7, lambda_l1=0.3, lambda_l2=0.5, learning_rate=0.12, max_depth=60, min_data_in_leaf=10, min_gain_to_split=0.22, num_class=3, num_leaves=25, objective=multiclass, verbose=-1;, score=-0.641 total time=  16.1s
# [CV 1/5] END bagging_fraction=0.8, bagging_freq=7, boosting_type=gbdt, feature_fraction=0.9, lambda_l1=0.4, lambda_l2=0.9, learning_rate=0.27, max_depth=29, min_data_in_leaf=16, min_gain_to_split=0.14, num_class=3, num_leaves=130, objective=multiclass, verbose=-1;, score=-0.686 total time=  28.5s
# [CV 2/5] END bagging_fraction=0.8, bagging_freq=7, boosting_type=gbdt, feature_fraction=0.9, lambda_l1=0.4, lambda_l2=0.9, learning_rate=0.27, max_depth=29, min_data_in_leaf=16, min_gain_to_split=0.14, num_class=3, num_leaves=130, objective=multiclass, verbose=-1;, score=-0.673 total time=  28.4s
# [CV 3/5] END bagging_fraction=0.8, bagging_freq=7, boosting_type=gbdt, feature_fraction=0.9, lambda_l1=0.4, lambda_l2=0.9, learning_rate=0.27, max_depth=29, min_data_in_leaf=16, min_gain_to_split=0.14, num_class=3, num_leaves=130, objective=multiclass, verbose=-1;, score=-0.657 total time=  28.9s
# [CV 4/5] END bagging_fraction=0.8, bagging_freq=7, boosting_type=gbdt, feature_fraction=0.9, lambda_l1=0.4, lambda_l2=0.9, learning_rate=0.27, max_depth=29, min_data_in_leaf=16, min_gain_to_split=0.14, num_class=3, num_leaves=130, objective=multiclass, verbose=-1;, score=-0.659 total time=  29.0s
# [CV 5/5] END bagging_fraction=0.8, bagging_freq=7, boosting_type=gbdt, feature_fraction=0.9, lambda_l1=0.4, lambda_l2=0.9, learning_rate=0.27, max_depth=29, min_data_in_leaf=16, min_gain_to_split=0.14, num_class=3, num_leaves=130, objective=multiclass, verbose=-1;, score=-0.670 total time=  28.9s
# [CV 1/5] END bagging_fraction=0.9, bagging_freq=1, boosting_type=gbdt, feature_fraction=0.7, lambda_l1=1.0, lambda_l2=0.2, learning_rate=0.3, max_depth=66, min_data_in_leaf=8, min_gain_to_split=0.11, num_class=3, num_leaves=146, objective=multiclass, verbose=-1;, score=-0.665 total time=  25.8s
# [CV 2/5] END bagging_fraction=0.9, bagging_freq=1, boosting_type=gbdt, feature_fraction=0.7, lambda_l1=1.0, lambda_l2=0.2, learning_rate=0.3, max_depth=66, min_data_in_leaf=8, min_gain_to_split=0.11, num_class=3, num_leaves=146, objective=multiclass, verbose=-1;, score=-0.677 total time=  25.0s
# [CV 3/5] END bagging_fraction=0.9, bagging_freq=1, boosting_type=gbdt, feature_fraction=0.7, lambda_l1=1.0, lambda_l2=0.2, learning_rate=0.3, max_depth=66, min_data_in_leaf=8, min_gain_to_split=0.11, num_class=3, num_leaves=146, objective=multiclass, verbose=-1;, score=-0.650 total time=  25.6s
# [CV 4/5] END bagging_fraction=0.9, bagging_freq=1, boosting_type=gbdt, feature_fraction=0.7, lambda_l1=1.0, lambda_l2=0.2, learning_rate=0.3, max_depth=66, min_data_in_leaf=8, min_gain_to_split=0.11, num_class=3, num_leaves=146, objective=multiclass, verbose=-1;, score=-0.659 total time=  27.4s
# [CV 5/5] END bagging_fraction=0.9, bagging_freq=1, boosting_type=gbdt, feature_fraction=0.7, lambda_l1=1.0, lambda_l2=0.2, learning_rate=0.3, max_depth=66, min_data_in_leaf=8, min_gain_to_split=0.11, num_class=3, num_leaves=146, objective=multiclass, verbose=-1;, score=-0.668 total time=  24.8s
# [CV 1/5] END bagging_fraction=0.8, bagging_freq=10, boosting_type=gbdt, feature_fraction=0.6, lambda_l1=0.9, lambda_l2=1.0, learning_rate=0.01, max_depth=38, min_data_in_leaf=15, min_gain_to_split=0.28, num_class=3, num_leaves=38, objective=multiclass, verbose=-1;, score=-0.668 total time=  20.4s
# [CV 2/5] END bagging_fraction=0.8, bagging_freq=10, boosting_type=gbdt, feature_fraction=0.6, lambda_l1=0.9, lambda_l2=1.0, learning_rate=0.01, max_depth=38, min_data_in_leaf=15, min_gain_to_split=0.28, num_class=3, num_leaves=38, objective=multiclass, verbose=-1;, score=-0.675 total time=  18.9s
# [CV 3/5] END bagging_fraction=0.8, bagging_freq=10, boosting_type=gbdt, feature_fraction=0.6, lambda_l1=0.9, lambda_l2=1.0, learning_rate=0.01, max_depth=38, min_data_in_leaf=15, min_gain_to_split=0.28, num_class=3, num_leaves=38, objective=multiclass, verbose=-1;, score=-0.651 total time=  18.7s
# [CV 4/5] END bagging_fraction=0.8, bagging_freq=10, boosting_type=gbdt, feature_fraction=0.6, lambda_l1=0.9, lambda_l2=1.0, learning_rate=0.01, max_depth=38, min_data_in_leaf=15, min_gain_to_split=0.28, num_class=3, num_leaves=38, objective=multiclass, verbose=-1;, score=-0.678 total time=  19.6s
# [CV 5/5] END bagging_fraction=0.8, bagging_freq=10, boosting_type=gbdt, feature_fraction=0.6, lambda_l1=0.9, lambda_l2=1.0, learning_rate=0.01, max_depth=38, min_data_in_leaf=15, min_gain_to_split=0.28, num_class=3, num_leaves=38, objective=multiclass, verbose=-1;, score=-0.690 total time=  19.3s
# [CV 1/5] END bagging_fraction=0.5, bagging_freq=5, boosting_type=gbdt, feature_fraction=0.5, lambda_l1=0.1, lambda_l2=0.2, learning_rate=0.1, max_depth=53, min_data_in_leaf=30, min_gain_to_split=0.08, num_class=3, num_leaves=40, objective=multiclass, verbose=-1;, score=-0.649 total time=  18.0s
# [CV 2/5] END bagging_fraction=0.5, bagging_freq=5, boosting_type=gbdt, feature_fraction=0.5, lambda_l1=0.1, lambda_l2=0.2, learning_rate=0.1, max_depth=53, min_data_in_leaf=30, min_gain_to_split=0.08, num_class=3, num_leaves=40, objective=multiclass, verbose=-1;, score=-0.636 total time=  17.9s
# [CV 3/5] END bagging_fraction=0.5, bagging_freq=5, boosting_type=gbdt, feature_fraction=0.5, lambda_l1=0.1, lambda_l2=0.2, learning_rate=0.1, max_depth=53, min_data_in_leaf=30, min_gain_to_split=0.08, num_class=3, num_leaves=40, objective=multiclass, verbose=-1;, score=-0.626 total time=  18.6s
# [CV 4/5] END bagging_fraction=0.5, bagging_freq=5, boosting_type=gbdt, feature_fraction=0.5, lambda_l1=0.1, lambda_l2=0.2, learning_rate=0.1, max_depth=53, min_data_in_leaf=30, min_gain_to_split=0.08, num_class=3, num_leaves=40, objective=multiclass, verbose=-1;, score=-0.636 total time=  18.6s
# [CV 5/5] END bagging_fraction=0.5, bagging_freq=5, boosting_type=gbdt, feature_fraction=0.5, lambda_l1=0.1, lambda_l2=0.2, learning_rate=0.1, max_depth=53, min_data_in_leaf=30, min_gain_to_split=0.08, num_class=3, num_leaves=40, objective=multiclass, verbose=-1;, score=-0.650 total time=  17.8s
# [CV 1/5] END bagging_fraction=0.9, bagging_freq=8, boosting_type=gbdt, feature_fraction=0.5, lambda_l1=0.2, lambda_l2=0.9, learning_rate=0.22, max_depth=38, min_data_in_leaf=8, min_gain_to_split=0.21, num_class=3, num_leaves=109, objective=multiclass, verbose=-1;, score=-0.667 total time=  28.8s
# [CV 2/5] END bagging_fraction=0.9, bagging_freq=8, boosting_type=gbdt, feature_fraction=0.5, lambda_l1=0.2, lambda_l2=0.9, learning_rate=0.22, max_depth=38, min_data_in_leaf=8, min_gain_to_split=0.21, num_class=3, num_leaves=109, objective=multiclass, verbose=-1;, score=-0.673 total time=  28.7s
# [CV 3/5] END bagging_fraction=0.9, bagging_freq=8, boosting_type=gbdt, feature_fraction=0.5, lambda_l1=0.2, lambda_l2=0.9, learning_rate=0.22, max_depth=38, min_data_in_leaf=8, min_gain_to_split=0.21, num_class=3, num_leaves=109, objective=multiclass, verbose=-1;, score=-0.647 total time=  30.2s
# [CV 4/5] END bagging_fraction=0.9, bagging_freq=8, boosting_type=gbdt, feature_fraction=0.5, lambda_l1=0.2, lambda_l2=0.9, learning_rate=0.22, max_depth=38, min_data_in_leaf=8, min_gain_to_split=0.21, num_class=3, num_leaves=109, objective=multiclass, verbose=-1;, score=-0.635 total time=  28.6s
# [CV 5/5] END bagging_fraction=0.9, bagging_freq=8, boosting_type=gbdt, feature_fraction=0.5, lambda_l1=0.2, lambda_l2=0.9, learning_rate=0.22, max_depth=38, min_data_in_leaf=8, min_gain_to_split=0.21, num_class=3, num_leaves=109, objective=multiclass, verbose=-1;, score=-0.673 total time=  28.2s
# [CV 1/5] END bagging_fraction=0.9, bagging_freq=4, boosting_type=gbdt, feature_fraction=0.7, lambda_l1=0.6, lambda_l2=0.8, learning_rate=0.31, max_depth=39, min_data_in_leaf=7, min_gain_to_split=0.16, num_class=3, num_leaves=114, objective=multiclass, verbose=-1;, score=-0.676 total time=  25.9s
# [CV 2/5] END bagging_fraction=0.9, bagging_freq=4, boosting_type=gbdt, feature_fraction=0.7, lambda_l1=0.6, lambda_l2=0.8, learning_rate=0.31, max_depth=39, min_data_in_leaf=7, min_gain_to_split=0.16, num_class=3, num_leaves=114, objective=multiclass, verbose=-1;, score=-0.678 total time=  26.8s
# [CV 3/5] END bagging_fraction=0.9, bagging_freq=4, boosting_type=gbdt, feature_fraction=0.7, lambda_l1=0.6, lambda_l2=0.8, learning_rate=0.31, max_depth=39, min_data_in_leaf=7, min_gain_to_split=0.16, num_class=3, num_leaves=114, objective=multiclass, verbose=-1;, score=-0.653 total time=  26.9s
# [CV 4/5] END bagging_fraction=0.9, bagging_freq=4, boosting_type=gbdt, feature_fraction=0.7, lambda_l1=0.6, lambda_l2=0.8, learning_rate=0.31, max_depth=39, min_data_in_leaf=7, min_gain_to_split=0.16, num_class=3, num_leaves=114, objective=multiclass, verbose=-1;, score=-0.653 total time=  26.9s
# [CV 5/5] END bagging_fraction=0.9, bagging_freq=4, boosting_type=gbdt, feature_fraction=0.7, lambda_l1=0.6, lambda_l2=0.8, learning_rate=0.31, max_depth=39, min_data_in_leaf=7, min_gain_to_split=0.16, num_class=3, num_leaves=114, objective=multiclass, verbose=-1;, score=-0.673 total time=  26.3s
# [CV 1/5] END bagging_fraction=0.7, bagging_freq=3, boosting_type=gbdt, feature_fraction=0.8, lambda_l1=0.6, lambda_l2=0.2, learning_rate=0.32, max_depth=64, min_data_in_leaf=20, min_gain_to_split=0.18, num_class=3, num_leaves=12, objective=multiclass, verbose=-1;, score=-0.658 total time=   9.6s
# [CV 2/5] END bagging_fraction=0.7, bagging_freq=3, boosting_type=gbdt, feature_fraction=0.8, lambda_l1=0.6, lambda_l2=0.2, learning_rate=0.32, max_depth=64, min_data_in_leaf=20, min_gain_to_split=0.18, num_class=3, num_leaves=12, objective=multiclass, verbose=-1;, score=-0.650 total time=  10.5s
# [CV 3/5] END bagging_fraction=0.7, bagging_freq=3, boosting_type=gbdt, feature_fraction=0.8, lambda_l1=0.6, lambda_l2=0.2, learning_rate=0.32, max_depth=64, min_data_in_leaf=20, min_gain_to_split=0.18, num_class=3, num_leaves=12, objective=multiclass, verbose=-1;, score=-0.619 total time=   9.8s
# [CV 4/5] END bagging_fraction=0.7, bagging_freq=3, boosting_type=gbdt, feature_fraction=0.8, lambda_l1=0.6, lambda_l2=0.2, learning_rate=0.32, max_depth=64, min_data_in_leaf=20, min_gain_to_split=0.18, num_class=3, num_leaves=12, objective=multiclass, verbose=-1;, score=-0.626 total time=   9.6s
# [CV 5/5] END bagging_fraction=0.7, bagging_freq=3, boosting_type=gbdt, feature_fraction=0.8, lambda_l1=0.6, lambda_l2=0.2, learning_rate=0.32, max_depth=64, min_data_in_leaf=20, min_gain_to_split=0.18, num_class=3, num_leaves=12, objective=multiclass, verbose=-1;, score=-0.642 total time=  10.6s
# [CV 1/5] END bagging_fraction=0.7, bagging_freq=4, boosting_type=gbdt, feature_fraction=0.5, lambda_l1=0.9, lambda_l2=0.4, learning_rate=0.13, max_depth=68, min_data_in_leaf=15, min_gain_to_split=0.13, num_class=3, num_leaves=173, objective=multiclass, verbose=-1;, score=-0.662 total time=  36.5s
# [CV 2/5] END bagging_fraction=0.7, bagging_freq=4, boosting_type=gbdt, feature_fraction=0.5, lambda_l1=0.9, lambda_l2=0.4, learning_rate=0.13, max_depth=68, min_data_in_leaf=15, min_gain_to_split=0.13, num_class=3, num_leaves=173, objective=multiclass, verbose=-1;, score=-0.667 total time=  35.0s
# [CV 3/5] END bagging_fraction=0.7, bagging_freq=4, boosting_type=gbdt, feature_fraction=0.5, lambda_l1=0.9, lambda_l2=0.4, learning_rate=0.13, max_depth=68, min_data_in_leaf=15, min_gain_to_split=0.13, num_class=3, num_leaves=173, objective=multiclass, verbose=-1;, score=-0.639 total time=  35.1s
# [CV 4/5] END bagging_fraction=0.7, bagging_freq=4, boosting_type=gbdt, feature_fraction=0.5, lambda_l1=0.9, lambda_l2=0.4, learning_rate=0.13, max_depth=68, min_data_in_leaf=15, min_gain_to_split=0.13, num_class=3, num_leaves=173, objective=multiclass, verbose=-1;, score=-0.641 total time=  34.2s
# [CV 5/5] END bagging_fraction=0.7, bagging_freq=4, boosting_type=gbdt, feature_fraction=0.5, lambda_l1=0.9, lambda_l2=0.4, learning_rate=0.13, max_depth=68, min_data_in_leaf=15, min_gain_to_split=0.13, num_class=3, num_leaves=173, objective=multiclass, verbose=-1;, score=-0.653 total time=  34.9s
# [CV 1/5] END bagging_fraction=0.7, bagging_freq=5, boosting_type=gbdt, feature_fraction=0.8, lambda_l1=0.1, lambda_l2=1.0, learning_rate=0.29, max_depth=43, min_data_in_leaf=8, min_gain_to_split=0.06, num_class=3, num_leaves=124, objective=multiclass, verbose=-1;, score=-0.686 total time=  42.9s
# [CV 2/5] END bagging_fraction=0.7, bagging_freq=5, boosting_type=gbdt, feature_fraction=0.8, lambda_l1=0.1, lambda_l2=1.0, learning_rate=0.29, max_depth=43, min_data_in_leaf=8, min_gain_to_split=0.06, num_class=3, num_leaves=124, objective=multiclass, verbose=-1;, score=-0.684 total time=  43.5s
# [CV 3/5] END bagging_fraction=0.7, bagging_freq=5, boosting_type=gbdt, feature_fraction=0.8, lambda_l1=0.1, lambda_l2=1.0, learning_rate=0.29, max_depth=43, min_data_in_leaf=8, min_gain_to_split=0.06, num_class=3, num_leaves=124, objective=multiclass, verbose=-1;, score=-0.655 total time=  43.7s
# [CV 4/5] END bagging_fraction=0.7, bagging_freq=5, boosting_type=gbdt, feature_fraction=0.8, lambda_l1=0.1, lambda_l2=1.0, learning_rate=0.29, max_depth=43, min_data_in_leaf=8, min_gain_to_split=0.06, num_class=3, num_leaves=124, objective=multiclass, verbose=-1;, score=-0.664 total time=  45.5s
# [CV 5/5] END bagging_fraction=0.7, bagging_freq=5, boosting_type=gbdt, feature_fraction=0.8, lambda_l1=0.1, lambda_l2=1.0, learning_rate=0.29, max_depth=43, min_data_in_leaf=8, min_gain_to_split=0.06, num_class=3, num_leaves=124, objective=multiclass, verbose=-1;, score=-0.675 total time=  43.3s
# [CV 1/5] END bagging_fraction=0.9, bagging_freq=3, boosting_type=gbdt, feature_fraction=0.8, lambda_l1=0.0, lambda_l2=0.0, learning_rate=0.1, max_depth=53, min_data_in_leaf=16, min_gain_to_split=0.15, num_class=3, num_leaves=81, objective=multiclass, verbose=-1;, score=-0.652 total time=  33.9s
# [CV 2/5] END bagging_fraction=0.9, bagging_freq=3, boosting_type=gbdt, feature_fraction=0.8, lambda_l1=0.0, lambda_l2=0.0, learning_rate=0.1, max_depth=53, min_data_in_leaf=16, min_gain_to_split=0.15, num_class=3, num_leaves=81, objective=multiclass, verbose=-1;, score=-0.655 total time=  34.4s
# [CV 3/5] END bagging_fraction=0.9, bagging_freq=3, boosting_type=gbdt, feature_fraction=0.8, lambda_l1=0.0, lambda_l2=0.0, learning_rate=0.1, max_depth=53, min_data_in_leaf=16, min_gain_to_split=0.15, num_class=3, num_leaves=81, objective=multiclass, verbose=-1;, score=-0.629 total time=  33.5s
# [CV 4/5] END bagging_fraction=0.9, bagging_freq=3, boosting_type=gbdt, feature_fraction=0.8, lambda_l1=0.0, lambda_l2=0.0, learning_rate=0.1, max_depth=53, min_data_in_leaf=16, min_gain_to_split=0.15, num_class=3, num_leaves=81, objective=multiclass, verbose=-1;, score=-0.635 total time=  33.4s
# [CV 5/5] END bagging_fraction=0.9, bagging_freq=3, boosting_type=gbdt, feature_fraction=0.8, lambda_l1=0.0, lambda_l2=0.0, learning_rate=0.1, max_depth=53, min_data_in_leaf=16, min_gain_to_split=0.15, num_class=3, num_leaves=81, objective=multiclass, verbose=-1;, score=-0.647 total time=  34.2s
# [CV 1/5] END bagging_fraction=0.8, bagging_freq=8, boosting_type=gbdt, feature_fraction=0.7, lambda_l1=0.7, lambda_l2=1.0, learning_rate=0.24, max_depth=6, min_data_in_leaf=17, min_gain_to_split=0.28, num_class=3, num_leaves=37, objective=multiclass, verbose=-1;, score=-0.651 total time=   7.0s
# ...
# [CV 5/5] END bagging_fraction=0.7, bagging_freq=6, boosting_type=gbdt, feature_fraction=0.7, lambda_l1=0.4, lambda_l2=0.2, learning_rate=0.37, max_depth=69, min_data_in_leaf=29, min_gain_to_split=0.08, num_class=3, num_leaves=163, objective=multiclass, verbose=-1;, score=-0.680 total time=  34.2s
# [CV 1/5] END bagging_fraction=0.7, bagging_freq=4, boosting_type=gbdt, feature_fraction=0.6, lambda_l1=0.7, lambda_l2=0.5, learning_rate=0.36, max_depth=11, min_data_in_leaf=8, min_gain_to_split=0.27, num_class=3, num_leaves=152, objective=multiclass, verbose=-1;, score=-0.672 total time=  12.3s
# [CV 2/5] END bagging_fraction=0.7, bagging_freq=4, boosting_type=gbdt, feature_fraction=0.6, lambda_l1=0.7, lambda_l2=0.5, learning_rate=0.36, max_depth=11, min_data_in_leaf=8, min_gain_to_split=0.27, num_class=3, num_leaves=152, objective=multiclass, verbose=-1;, score=-0.674 total time=  12.4s
# [CV 3/5] END bagging_fraction=0.7, bagging_freq=4, boosting_type=gbdt, feature_fraction=0.6, lambda_l1=0.7, lambda_l2=0.5, learning_rate=0.36, max_depth=11, min_data_in_leaf=8, min_gain_to_split=0.27, num_class=3, num_leaves=152, objective=multiclass, verbose=-1;, score=-0.636 total time=  13.1s
# [CV 4/5] END bagging_fraction=0.7, bagging_freq=4, boosting_type=gbdt, feature_fraction=0.6, lambda_l1=0.7, lambda_l2=0.5, learning_rate=0.36, max_depth=11, min_data_in_leaf=8, min_gain_to_split=0.27, num_class=3, num_leaves=152, objective=multiclass, verbose=-1;, score=-0.654 total time=  13.1s
# [CV 5/5] END bagging_fraction=0.7, bagging_freq=4, boosting_type=gbdt, feature_fraction=0.6, lambda_l1=0.7, lambda_l2=0.5, learning_rate=0.36, max_depth=11, min_data_in_leaf=8, min_gain_to_split=0.27, num_class=3, num_leaves=152, objective=multiclass, verbose=-1;, score=-0.670 total time=  13.1s
# [CV 1/5] END bagging_fraction=0.9, bagging_freq=5, boosting_type=gbdt, feature_fraction=0.7, lambda_l1=0.9, lambda_l2=0.6, learning_rate=0.45, max_depth=20, min_data_in_leaf=11, min_gain_to_split=0.12, num_class=3, num_leaves=165, objective=multiclass, verbose=-1;, score=-0.684 total time=  17.9s
# [CV 2/5] END bagging_fraction=0.9, bagging_freq=5, boosting_type=gbdt, feature_fraction=0.7, lambda_l1=0.9, lambda_l2=0.6, learning_rate=0.45, max_depth=20, min_data_in_leaf=11, min_gain_to_split=0.12, num_class=3, num_leaves=165, objective=multiclass, verbose=-1;, score=-0.673 total time=  17.8s
# [CV 3/5] END bagging_fraction=0.9, bagging_freq=5, boosting_type=gbdt, feature_fraction=0.7, lambda_l1=0.9, lambda_l2=0.6, learning_rate=0.45, max_depth=20, min_data_in_leaf=11, min_gain_to_split=0.12, num_class=3, num_leaves=165, objective=multiclass, verbose=-1;, score=-0.658 total time=  18.9s
# [CV 4/5] END bagging_fraction=0.9, bagging_freq=5, boosting_type=gbdt, feature_fraction=0.7, lambda_l1=0.9, lambda_l2=0.6, learning_rate=0.45, max_depth=20, min_data_in_leaf=11, min_gain_to_split=0.12, num_class=3, num_leaves=165, objective=multiclass, verbose=-1;, score=-0.662 total time=  18.2s
# [CV 5/5] END bagging_fraction=0.9, bagging_freq=5, boosting_type=gbdt, feature_fraction=0.7, lambda_l1=0.9, lambda_l2=0.6, learning_rate=0.45, max_depth=20, min_data_in_leaf=11, min_gain_to_split=0.12, num_class=3, num_leaves=165, objective=multiclass, verbose=-1;, score=-0.689 total time=  19.2s
# [CV 1/5] END bagging_fraction=0.7, bagging_freq=10, boosting_type=gbdt, feature_fraction=0.7, lambda_l1=0.3, lambda_l2=0.4, learning_rate=0.37, max_depth=40, min_data_in_leaf=20, min_gain_to_split=0.28, num_class=3, num_leaves=117, objective=multiclass, verbose=-1;, score=-0.691 total time=  21.1s
# [CV 2/5] END bagging_fraction=0.7, bagging_freq=10, boosting_type=gbdt, feature_fraction=0.7, lambda_l1=0.3, lambda_l2=0.4, learning_rate=0.37, max_depth=40, min_data_in_leaf=20, min_gain_to_split=0.28, num_class=3, num_leaves=117, objective=multiclass, verbose=-1;, score=-0.679 total time=  21.1s
# [CV 3/5] END bagging_fraction=0.7, bagging_freq=10, boosting_type=gbdt, feature_fraction=0.7, lambda_l1=0.3, lambda_l2=0.4, learning_rate=0.37, max_depth=40, min_data_in_leaf=20, min_gain_to_split=0.28, num_class=3, num_leaves=117, objective=multiclass, verbose=-1;, score=-0.655 total time=  20.6s
# [CV 4/5] END bagging_fraction=0.7, bagging_freq=10, boosting_type=gbdt, feature_fraction=0.7, lambda_l1=0.3, lambda_l2=0.4, learning_rate=0.37, max_depth=40, min_data_in_leaf=20, min_gain_to_split=0.28, num_class=3, num_leaves=117, objective=multiclass, verbose=-1;, score=-0.663 total time=  21.8s
# [CV 5/5] END bagging_fraction=0.7, bagging_freq=10, boosting_type=gbdt, feature_fraction=0.7, lambda_l1=0.3, lambda_l2=0.4, learning_rate=0.37, max_depth=40, min_data_in_leaf=20, min_gain_to_split=0.28, num_class=3, num_leaves=117, objective=multiclass, verbose=-1;, score=-0.681 total time=  20.2s
# [CV 1/5] END bagging_fraction=0.7, bagging_freq=5, boosting_type=gbdt, feature_fraction=0.8, lambda_l1=0.2, lambda_l2=0.8, learning_rate=0.45, max_depth=26, min_data_in_leaf=18, min_gain_to_split=0.16, num_class=3, num_leaves=37, objective=multiclass, verbose=-1;, score=-0.682 total time=  20.3s
# [CV 2/5] END bagging_fraction=0.7, bagging_freq=5, boosting_type=gbdt, feature_fraction=0.8, lambda_l1=0.2, lambda_l2=0.8, learning_rate=0.45, max_depth=26, min_data_in_leaf=18, min_gain_to_split=0.16, num_class=3, num_leaves=37, objective=multiclass, verbose=-1;, score=-0.685 total time=  21.6s
# [CV 3/5] END bagging_fraction=0.7, bagging_freq=5, boosting_type=gbdt, feature_fraction=0.8, lambda_l1=0.2, lambda_l2=0.8, learning_rate=0.45, max_depth=26, min_data_in_leaf=18, min_gain_to_split=0.16, num_class=3, num_leaves=37, objective=multiclass, verbose=-1;, score=-0.644 total time=  19.7s
# [CV 4/5] END bagging_fraction=0.7, bagging_freq=5, boosting_type=gbdt, feature_fraction=0.8, lambda_l1=0.2, lambda_l2=0.8, learning_rate=0.45, max_depth=26, min_data_in_leaf=18, min_gain_to_split=0.16, num_class=3, num_leaves=37, objective=multiclass, verbose=-1;, score=-0.672 total time=  20.7s
# [CV 5/5] END bagging_fraction=0.7, bagging_freq=5, boosting_type=gbdt, feature_fraction=0.8, lambda_l1=0.2, lambda_l2=0.8, learning_rate=0.45, max_depth=26, min_data_in_leaf=18, min_gain_to_split=0.16, num_class=3, num_leaves=37, objective=multiclass, verbose=-1;, score=-0.676 total time=  20.1s
# [CV 1/5] END bagging_fraction=0.6, bagging_freq=1, boosting_type=gbdt, feature_fraction=0.9, lambda_l1=0.0, lambda_l2=0.2, learning_rate=0.41, max_depth=28, min_data_in_leaf=29, min_gain_to_split=0.09, num_class=3, num_leaves=55, objective=multiclass, verbose=-1;, score=-0.692 total time=  18.7s
# [CV 2/5] END bagging_fraction=0.6, bagging_freq=1, boosting_type=gbdt, feature_fraction=0.9, lambda_l1=0.0, lambda_l2=0.2, learning_rate=0.41, max_depth=28, min_data_in_leaf=29, min_gain_to_split=0.09, num_class=3, num_leaves=55, objective=multiclass, verbose=-1;, score=-0.671 total time=  19.0s
# [CV 3/5] END bagging_fraction=0.6, bagging_freq=1, boosting_type=gbdt, feature_fraction=0.9, lambda_l1=0.0, lambda_l2=0.2, learning_rate=0.41, max_depth=28, min_data_in_leaf=29, min_gain_to_split=0.09, num_class=3, num_leaves=55, objective=multiclass, verbose=-1;, score=-0.673 total time=  19.4s
# [CV 4/5] END bagging_fraction=0.6, bagging_freq=1, boosting_type=gbdt, feature_fraction=0.9, lambda_l1=0.0, lambda_l2=0.2, learning_rate=0.41, max_depth=28, min_data_in_leaf=29, min_gain_to_split=0.09, num_class=3, num_leaves=55, objective=multiclass, verbose=-1;, score=-0.672 total time=  18.6s
# [CV 5/5] END bagging_fraction=0.6, bagging_freq=1, boosting_type=gbdt, feature_fraction=0.9, lambda_l1=0.0, lambda_l2=0.2, learning_rate=0.41, max_depth=28, min_data_in_leaf=29, min_gain_to_split=0.09, num_class=3, num_leaves=55, objective=multiclass, verbose=-1;, score=-0.687 total time=  20.3s
# [CV 1/5] END bagging_fraction=0.6, bagging_freq=2, boosting_type=gbdt, feature_fraction=0.6, lambda_l1=1.0, lambda_l2=0.1, learning_rate=0.1, max_depth=22, min_data_in_leaf=13, min_gain_to_split=0.1, num_class=3, num_leaves=146, objective=multiclass, verbose=-1;, score=-0.641 total time=  24.2s
# [CV 2/5] END bagging_fraction=0.6, bagging_freq=2, boosting_type=gbdt, feature_fraction=0.6, lambda_l1=1.0, lambda_l2=0.1, learning_rate=0.1, max_depth=22, min_data_in_leaf=13, min_gain_to_split=0.1, num_class=3, num_leaves=146, objective=multiclass, verbose=-1;, score=-0.648 total time=  23.2s
# [CV 3/5] END bagging_fraction=0.6, bagging_freq=2, boosting_type=gbdt, feature_fraction=0.6, lambda_l1=1.0, lambda_l2=0.1, learning_rate=0.1, max_depth=22, min_data_in_leaf=13, min_gain_to_split=0.1, num_class=3, num_leaves=146, objective=multiclass, verbose=-1;, score=-0.631 total time=  23.8s
# [CV 4/5] END bagging_fraction=0.6, bagging_freq=2, boosting_type=gbdt, feature_fraction=0.6, lambda_l1=1.0, lambda_l2=0.1, learning_rate=0.1, max_depth=22, min_data_in_leaf=13, min_gain_to_split=0.1, num_class=3, num_leaves=146, objective=multiclass, verbose=-1;, score=-0.633 total time=  24.3s
# [CV 5/5] END bagging_fraction=0.6, bagging_freq=2, boosting_type=gbdt, feature_fraction=0.6, lambda_l1=1.0, lambda_l2=0.1, learning_rate=0.1, max_depth=22, min_data_in_leaf=13, min_gain_to_split=0.1, num_class=3, num_leaves=146, objective=multiclass, verbose=-1;, score=-0.657 total time=  22.6s
# [CV 1/5] END bagging_fraction=0.8, bagging_freq=4, boosting_type=gbdt, feature_fraction=0.6, lambda_l1=0.5, lambda_l2=0.0, learning_rate=0.4, max_depth=16, min_data_in_leaf=9, min_gain_to_split=0.17, num_class=3, num_leaves=140, objective=multiclass, verbose=-1;, score=-0.679 total time=  17.2s
# [CV 2/5] END bagging_fraction=0.8, bagging_freq=4, boosting_type=gbdt, feature_fraction=0.6, lambda_l1=0.5, lambda_l2=0.0, learning_rate=0.4, max_depth=16, min_data_in_leaf=9, min_gain_to_split=0.17, num_class=3, num_leaves=140, objective=multiclass, verbose=-1;, score=-0.668 total time=  18.1s
# [CV 3/5] END bagging_fraction=0.8, bagging_freq=4, boosting_type=gbdt, feature_fraction=0.6, lambda_l1=0.5, lambda_l2=0.0, learning_rate=0.4, max_depth=16, min_data_in_leaf=9, min_gain_to_split=0.17, num_class=3, num_leaves=140, objective=multiclass, verbose=-1;, score=-0.635 total time=  17.7s
# [CV 4/5] END bagging_fraction=0.8, bagging_freq=4, boosting_type=gbdt, feature_fraction=0.6, lambda_l1=0.5, lambda_l2=0.0, learning_rate=0.4, max_depth=16, min_data_in_leaf=9, min_gain_to_split=0.17, num_class=3, num_leaves=140, objective=multiclass, verbose=-1;, score=-0.644 total time=  17.3s
# [CV 5/5] END bagging_fraction=0.8, bagging_freq=4, boosting_type=gbdt, feature_fraction=0.6, lambda_l1=0.5, lambda_l2=0.0, learning_rate=0.4, max_depth=16, min_data_in_leaf=9, min_gain_to_split=0.17, num_class=3, num_leaves=140, objective=multiclass, verbose=-1;, score=-0.686 total time=  17.0s
# [CV 1/5] END bagging_fraction=0.7, bagging_freq=8, boosting_type=gbdt, feature_fraction=0.5, lambda_l1=1.0, lambda_l2=0.1, learning_rate=0.16, max_depth=29, min_data_in_leaf=12, min_gain_to_split=0.17, num_class=3, num_leaves=155, objective=multiclass, verbose=-1;, score=-0.674 total time=  23.5s
# [CV 2/5] END bagging_fraction=0.7, bagging_freq=8, boosting_type=gbdt, feature_fraction=0.5, lambda_l1=1.0, lambda_l2=0.1, learning_rate=0.16, max_depth=29, min_data_in_leaf=12, min_gain_to_split=0.17, num_class=3, num_leaves=155, objective=multiclass, verbose=-1;, score=-0.653 total time=  22.0s
# [CV 3/5] END bagging_fraction=0.7, bagging_freq=8, boosting_type=gbdt, feature_fraction=0.5, lambda_l1=1.0, lambda_l2=0.1, learning_rate=0.16, max_depth=29, min_data_in_leaf=12, min_gain_to_split=0.17, num_class=3, num_leaves=155, objective=multiclass, verbose=-1;, score=-0.634 total time=  23.5s
# [CV 4/5] END bagging_fraction=0.7, bagging_freq=8, boosting_type=gbdt, feature_fraction=0.5, lambda_l1=1.0, lambda_l2=0.1, learning_rate=0.16, max_depth=29, min_data_in_leaf=12, min_gain_to_split=0.17, num_class=3, num_leaves=155, objective=multiclass, verbose=-1;, score=-0.641 total time=  24.1s
# [CV 5/5] END bagging_fraction=0.7, bagging_freq=8, boosting_type=gbdt, feature_fraction=0.5, lambda_l1=1.0, lambda_l2=0.1, learning_rate=0.16, max_depth=29, min_data_in_leaf=12, min_gain_to_split=0.17, num_class=3, num_leaves=155, objective=multiclass, verbose=-1;, score=-0.652 total time=  23.1s
# [CV 1/5] END bagging_fraction=0.6, bagging_freq=9, boosting_type=gbdt, feature_fraction=0.9, lambda_l1=0.7, lambda_l2=0.0, learning_rate=0.34, max_depth=53, min_data_in_leaf=5, min_gain_to_split=0.22, num_class=3, num_leaves=80, objective=multiclass, verbose=-1;, score=-0.694 total time=  26.2s
# [CV 2/5] END bagging_fraction=0.6, bagging_freq=9, boosting_type=gbdt, feature_fraction=0.9, lambda_l1=0.7, lambda_l2=0.0, learning_rate=0.34, max_depth=53, min_data_in_leaf=5, min_gain_to_split=0.22, num_class=3, num_leaves=80, objective=multiclass, verbose=-1;, score=-0.684 total time=  27.2s
# [CV 3/5] END bagging_fraction=0.6, bagging_freq=9, boosting_type=gbdt, feature_fraction=0.9, lambda_l1=0.7, lambda_l2=0.0, learning_rate=0.34, max_depth=53, min_data_in_leaf=5, min_gain_to_split=0.22, num_class=3, num_leaves=80, objective=multiclass, verbose=-1;, score=-0.677 total time=  27.5s
# [CV 4/5] END bagging_fraction=0.6, bagging_freq=9, boosting_type=gbdt, feature_fraction=0.9, lambda_l1=0.7, lambda_l2=0.0, learning_rate=0.34, max_depth=53, min_data_in_leaf=5, min_gain_to_split=0.22, num_class=3, num_leaves=80, objective=multiclass, verbose=-1;, score=-0.678 total time=  27.9s
# [CV 5/5] END bagging_fraction=0.6, bagging_freq=9, boosting_type=gbdt, feature_fraction=0.9, lambda_l1=0.7, lambda_l2=0.0, learning_rate=0.34, max_depth=53, min_data_in_leaf=5, min_gain_to_split=0.22, num_class=3, num_leaves=80, objective=multiclass, verbose=-1;, score=-0.684 total time=  27.4s
# [CV 1/5] END bagging_fraction=0.7, bagging_freq=6, boosting_type=gbdt, feature_fraction=0.6, lambda_l1=0.7, lambda_l2=0.1, learning_rate=0.18, max_depth=29, min_data_in_leaf=15, min_gain_to_split=0.28, num_class=3, num_leaves=134, objective=multiclass, verbose=-1;, score=-0.670 total time=  21.1s
# [CV 2/5] END bagging_fraction=0.7, bagging_freq=6, boosting_type=gbdt, feature_fraction=0.6, lambda_l1=0.7, lambda_l2=0.1, learning_rate=0.18, max_depth=29, min_data_in_leaf=15, min_gain_to_split=0.28, num_class=3, num_leaves=134, objective=multiclass, verbose=-1;, score=-0.661 total time=  22.2s
# [CV 3/5] END bagging_fraction=0.7, bagging_freq=6, boosting_type=gbdt, feature_fraction=0.6, lambda_l1=0.7, lambda_l2=0.1, learning_rate=0.18, max_depth=29, min_data_in_leaf=15, min_gain_to_split=0.28, num_class=3, num_leaves=134, objective=multiclass, verbose=-1;, score=-0.631 total time=  21.9s
# [CV 4/5] END bagging_fraction=0.7, bagging_freq=6, boosting_type=gbdt, feature_fraction=0.6, lambda_l1=0.7, lambda_l2=0.1, learning_rate=0.18, max_depth=29, min_data_in_leaf=15, min_gain_to_split=0.28, num_class=3, num_leaves=134, objective=multiclass, verbose=-1;, score=-0.647 total time=  22.3s
# [CV 5/5] END bagging_fraction=0.7, bagging_freq=6, boosting_type=gbdt, feature_fraction=0.6, lambda_l1=0.7, lambda_l2=0.1, learning_rate=0.18, max_depth=29, min_data_in_leaf=15, min_gain_to_split=0.28, num_class=3, num_leaves=134, objective=multiclass, verbose=-1;, score=-0.668 total time=  22.0s
# Best Parameters: {'verbose': -1, 'objective': 'multiclass', 'num_leaves': 20, 'num_class': 3, 'min_gain_to_split': 0.16, 'min_data_in_leaf': 18, 'max_depth': 68, 'learning_rate': 0.12, 'lambda_l2': 0.7, 'lambda_l1': 0.7, 'feature_fraction': 0.9, 'boosting_type': 'gbdt', 'bagging_freq': 10, 'bagging_fraction': 0.7}
# Best score found:  0.6327580050522188
# Best estimator: LGBMClassifier(bagging_fraction=0.7, bagging_freq=10, feature_fraction=0.9,
#                lambda_l1=0.7, lambda_l2=0.7, learning_rate=0.12, max_depth=68,
#                min_data_in_leaf=18, min_gain_to_split=0.16, num_class=3,
#                num_leaves=20, objective='multiclass', random_state=42,
#                verbose=-1)
# Execution time: 3 hours, 9 minutes, 3 seconds

# %% [raw]
# Best Parameters: {'verbose': -1, 'objective': 'multiclass', 'num_leaves': 20, 'num_class': 3, 'min_gain_to_split': 0.16, 'min_data_in_leaf': 18, 'max_depth': 68, 'learning_rate': 0.12, 'lambda_l2': 0.7, 'lambda_l1': 0.7, 'feature_fraction': 0.9, 'boosting_type': 'gbdt', 'bagging_freq': 10, 'bagging_fraction': 0.7}
# Best score found:  0.6327580050522188
# Best estimator: LGBMClassifier(bagging_fraction=0.7, bagging_freq=10, feature_fraction=0.9,
#                lambda_l1=0.7, lambda_l2=0.7, learning_rate=0.12, max_depth=68,
#                min_data_in_leaf=18, min_gain_to_split=0.16, num_class=3,
#                num_leaves=20, objective='multiclass', random_state=42,
#                verbose=-1)
# Execution time: 3 hours, 9 minutes, 3 seconds

# %%
# Save Randomized and 5CV results
LGBM_UBTnofeat_CV = pd.DataFrame(lgbm_random.cv_results_)
LGBM_UBTnofeat_CV.to_csv('/content/drive/MyDrive/3_classes/LGBM_UBTnofeat_CV.csv', index=False)
box_fig = pd.read_csv('/content/drive/MyDrive/3_classes/LGBM_UBTnofeat_CV.csv')

# %%
# Boxplot MAE Scores for each fold
plt.figure(figsize=(8, 6))
numeric_cols = ['split0_test_score', 'split1_test_score', 'split2_test_score', 'split3_test_score', 'split4_test_score']
box_fig[numeric_cols] = box_fig[numeric_cols].abs()
bp = box_fig.boxplot(column=numeric_cols, patch_artist=True)
plt.xlabel('Fold')
plt.ylabel('MAE Score')
plt.title('LightGBM MAE Scores for Each Cross Validation Fold')
plt.xticks(ticks=range(1, 6), labels=[f'Fold {i+1}' for i in range(5)])
plt.grid(True)
plt.tight_layout()
plt.savefig('/content/drive/MyDrive/3_classes/MAE_perFold.png', dpi=300, bbox_inches='tight')  # Save as PNG
plt.show()

# %%
# Plot MAE scores average per cross validation
cv_scores = -box_fig['mean_test_score']
plt.plot(range(1, len(cv_scores) + 1), cv_scores, '-o', label='Average MAE across folds per iteration', color='#1f77b4')

plt.xlabel('Numbers of iterations', fontsize=14, labelpad=10)
plt.ylabel('MAE', fontsize=14, labelpad=10)
plt.title('LightGBM 5-Fold Cross Validation MAE per Iteration', fontsize=16, pad=20)
plt.grid(True, linestyle='--', linewidth=0.5, alpha=0.5)
plt.tick_params(axis='both', which='major', labelsize=12)
plt.ylim(0.5, 0.8)
plt.legend(fontsize=12)
plt.tight_layout()
plt.savefig('/content/drive/MyDrive/3_classes/LGBM_avg_mae_iteration', dpi=300, bbox_inches='tight')  # Save as PNG
plt.show()

# %%
# Trained LGBM predict test data with best estimator
lgb_random1 = lgbm_random.best_estimator_
y_pred = lgb_random1.predict(X_test)

# %%
# Evaluation
lgbm_mae = mean_absolute_error(y_test, y_pred)
print(f'Test MAE: {lgbm_mae:.3f}')
lgbm_mse = mean_squared_error(y_test, y_pred)
lgbm_rmse = lgbm_mse ** 0.5
print(f'Test RMSE: {lgbm_rmse:.3f}')
lgbm_kappa = cohen_kappa_score(y_test, y_pred, weights='quadratic')
print(f'Test CWK: {lgbm_kappa:.3f}')

# Confusion matrix
class_labels = {1: 'challenging', 2: 'moderate', 3: 'user-friendly'}
conf_matrix = confusion_matrix(y_test, y_pred)
conf_matrix_percent = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]
plt.figure(figsize=(8, 6))
plt.imshow(conf_matrix_percent, cmap=plt.cm.Blues, vmin=0, vmax=1)
plt.title('Confusion Matrix LightGBM')
plt.colorbar(label='Percentage')
for i in range(conf_matrix.shape[0]):
    for j in range(conf_matrix.shape[1]):
        plt.text(j, i, f'{conf_matrix_percent[i, j]:.2f}', ha='center', va='center', color='black')

plt.xlabel('Predicted class')
plt.ylabel('True class')
plt.xticks(np.arange(len(class_labels)), [class_labels[i] for i in sorted(class_labels)], rotation=45)
plt.yticks(np.arange(len(class_labels)), [class_labels[i] for i in sorted(class_labels)])

plt.savefig('/content/drive/MyDrive/3_classes/LGBM_confusionmatrix.png', dpi=300, bbox_inches='tight')  # Save as PNG
plt.tight_layout()
plt.show()
# Out:
# Test MAE: 0.642
# Test RMSE: 0.983
# Test CWK: 0.306

# %%
# Feature importance LightGBM
feature_importance = lgb_random1.feature_importances_
feature_names = X_train.columns
feature_importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': feature_importance})
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# Top 30
n = 30
plt.figure(figsize=(15, 15))
plt.barh(range(n), feature_importance_df['Importance'].head(n), align='center')
plt.yticks(range(n), feature_importance_df['Feature'].head(n))
plt.xlabel('Feature Importance')
plt.ylabel('Feature')
plt.title('LightGBM Top 30 Most Important Features')
plt.gca().invert_yaxis()
plt.savefig('/content/drive/MyDrive/3_classes/LGBM_featureimportance', dpi=300, bbox_inches='tight')  # Save as PNG
plt.show()

# %% [markdown]
# ## SVC with unigrams, bigrams and polarity score, without features 'Age', 'Gender'

# %%
# Perform scaling voor SVM, run for SVM
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# Hyperparameter tuning SVC GidSearch
start_time = time.time()

param_grid = {
    'C': [0.1, 1, 10, 100, 1000],
    'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
    'kernel': ['rbf'],
    'decision_function_shape': ['ovr'],
    'class_weight': ['balanced'], 
} 

k_fold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)   
svm_classifier = SVC(random_state=42)
svm_random = GridSearchCV(estimator=svm_classifier,
                                param_grid=param_grid,                
                                cv=k_fold,                        
                                scoring='neg_mean_absolute_error',          
                                n_jobs=5,
                                verbose = 3)  

svm_random.fit(X_train, y_train)

print("Best Parameters:", svm_random.best_params_)
print("Best score found: ",-svm_random.best_score_)
print ('Best estimator:', svm_random.best_estimator_)

end_time = time.time()
elapsed_time = end_time - start_time
hours, remainder = divmod(elapsed_time, 3600)
minutes, seconds = divmod(remainder, 60)
print(f"Execution time: {int(hours)} hours, {int(minutes)} minutes, {int(seconds)} seconds")
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV 5/5] END C=0.1, class_weight=balanced, decision_function_shape=ovr, gamma=1, kernel=rbf;, score=-0.996 total time=15.5min
# [CV 1/5] END C=0.1, class_weight=balanced, decision_function_shape=ovr, gamma=1, kernel=rbf;, score=-0.995 total time=15.8min
# [CV 2/5] END C=0.1, class_weight=balanced, decision_function_shape=ovr, gamma=1, kernel=rbf;, score=-0.998 total time=16.3min
# [CV 3/5] END C=0.1, class_weight=balanced, decision_function_shape=ovr, gamma=1, kernel=rbf;, score=-0.995 total time=16.3min
# [CV 4/5] END C=0.1, class_weight=balanced, decision_function_shape=ovr, gamma=1, kernel=rbf;, score=-0.998 total time=16.3min
# [CV 1/5] END C=0.1, class_weight=balanced, decision_function_shape=ovr, gamma=0.1, kernel=rbf;, score=-0.996 total time=15.8min
# [CV 5/5] END C=0.1, class_weight=balanced, decision_function_shape=ovr, gamma=0.1, kernel=rbf;, score=-0.996 total time=15.4min
# [CV 2/5] END C=0.1, class_weight=balanced, decision_function_shape=ovr, gamma=0.1, kernel=rbf;, score=-0.998 total time=16.2min
# [CV 4/5] END C=0.1, class_weight=balanced, decision_function_shape=ovr, gamma=0.1, kernel=rbf;, score=-0.998 total time=16.2min
# [CV 3/5] END C=0.1, class_weight=balanced, decision_function_shape=ovr, gamma=0.1, kernel=rbf;, score=-0.995 total time=16.2min
# [CV 1/5] END C=0.1, class_weight=balanced, decision_function_shape=ovr, gamma=0.01, kernel=rbf;, score=-0.996 total time=15.8min
# [CV 2/5] END C=0.1, class_weight=balanced, decision_function_shape=ovr, gamma=0.01, kernel=rbf;, score=-0.997 total time=16.1min
# [CV 3/5] END C=0.1, class_weight=balanced, decision_function_shape=ovr, gamma=0.01, kernel=rbf;, score=-0.996 total time=16.2min
# [CV 5/5] END C=0.1, class_weight=balanced, decision_function_shape=ovr, gamma=0.01, kernel=rbf;, score=-0.996 total time=15.8min
# [CV 4/5] END C=0.1, class_weight=balanced, decision_function_shape=ovr, gamma=0.01, kernel=rbf;, score=-0.998 total time=16.2min
# [CV 1/5] END C=0.1, class_weight=balanced, decision_function_shape=ovr, gamma=0.001, kernel=rbf;, score=-0.697 total time=14.9min
# [CV 5/5] END C=0.1, class_weight=balanced, decision_function_shape=ovr, gamma=0.001, kernel=rbf;, score=-0.692 total time=14.2min
# [CV 2/5] END C=0.1, class_weight=balanced, decision_function_shape=ovr, gamma=0.001, kernel=rbf;, score=-0.681 total time=15.1min
# [CV 3/5] END C=0.1, class_weight=balanced, decision_function_shape=ovr, gamma=0.001, kernel=rbf;, score=-0.673 total time=15.0min
# [CV 4/5] END C=0.1, class_weight=balanced, decision_function_shape=ovr, gamma=0.001, kernel=rbf;, score=-0.671 total time=14.9min
# [CV 1/5] END C=0.1, class_weight=balanced, decision_function_shape=ovr, gamma=0.0001, kernel=rbf;, score=-0.730 total time=10.7min
# [CV 2/5] END C=0.1, class_weight=balanced, decision_function_shape=ovr, gamma=0.0001, kernel=rbf;, score=-0.705 total time=10.5min
# [CV 3/5] END C=0.1, class_weight=balanced, decision_function_shape=ovr, gamma=0.0001, kernel=rbf;, score=-0.656 total time=10.6min
# [CV 4/5] END C=0.1, class_weight=balanced, decision_function_shape=ovr, gamma=0.0001, kernel=rbf;, score=-0.634 total time=10.5min
# [CV 5/5] END C=0.1, class_weight=balanced, decision_function_shape=ovr, gamma=0.0001, kernel=rbf;, score=-0.727 total time=10.4min
# [CV 1/5] END C=1, class_weight=balanced, decision_function_shape=ovr, gamma=1, kernel=rbf;, score=-0.994 total time=14.5min
# [CV 5/5] END C=1, class_weight=balanced, decision_function_shape=ovr, gamma=1, kernel=rbf;, score=-0.992 total time=13.8min
# [CV 2/5] END C=1, class_weight=balanced, decision_function_shape=ovr, gamma=1, kernel=rbf;, score=-0.990 total time=14.9min
# [CV 4/5] END C=1, class_weight=balanced, decision_function_shape=ovr, gamma=1, kernel=rbf;, score=-0.994 total time=17.4min
# [CV 3/5] END C=1, class_weight=balanced, decision_function_shape=ovr, gamma=1, kernel=rbf;, score=-0.993 total time=17.6min
# [CV 1/5] END C=1, class_weight=balanced, decision_function_shape=ovr, gamma=0.1, kernel=rbf;, score=-0.991 total time=14.4min
# [CV 2/5] END C=1, class_weight=balanced, decision_function_shape=ovr, gamma=0.1, kernel=rbf;, score=-0.989 total time=14.9min
# [CV 5/5] END C=1, class_weight=balanced, decision_function_shape=ovr, gamma=0.1, kernel=rbf;, score=-0.991 total time=15.2min
# [CV 3/5] END C=1, class_weight=balanced, decision_function_shape=ovr, gamma=0.1, kernel=rbf;, score=-0.992 total time=18.0min
# [CV 4/5] END C=1, class_weight=balanced, decision_function_shape=ovr, gamma=0.1, kernel=rbf;, score=-0.994 total time=17.8min
# [CV 1/5] END C=1, class_weight=balanced, decision_function_shape=ovr, gamma=0.01, kernel=rbf;, score=-0.934 total time=15.5min
# [CV 2/5] END C=1, class_weight=balanced, decision_function_shape=ovr, gamma=0.01, kernel=rbf;, score=-0.957 total time=16.0min
# [CV 5/5] END C=1, class_weight=balanced, decision_function_shape=ovr, gamma=0.01, kernel=rbf;, score=-0.962 total time=16.6min
# [CV 4/5] END C=1, class_weight=balanced, decision_function_shape=ovr, gamma=0.01, kernel=rbf;, score=-0.955 total time=19.4min
# [CV 3/5] END C=1, class_weight=balanced, decision_function_shape=ovr, gamma=0.01, kernel=rbf;, score=-0.954 total time=19.6min
# [CV 1/5] END C=1, class_weight=balanced, decision_function_shape=ovr, gamma=0.001, kernel=rbf;, score=-0.642 total time=11.9min
# [CV 2/5] END C=1, class_weight=balanced, decision_function_shape=ovr, gamma=0.001, kernel=rbf;, score=-0.647 total time=11.9min
# [CV 3/5] END C=1, class_weight=balanced, decision_function_shape=ovr, gamma=0.001, kernel=rbf;, score=-0.626 total time=12.1min
# [CV 5/5] END C=1, class_weight=balanced, decision_function_shape=ovr, gamma=0.001, kernel=rbf;, score=-0.641 total time=11.9min
# [CV 4/5] END C=1, class_weight=balanced, decision_function_shape=ovr, gamma=0.001, kernel=rbf;, score=-0.631 total time=12.1min
# [CV 1/5] END C=1, class_weight=balanced, decision_function_shape=ovr, gamma=0.0001, kernel=rbf;, score=-0.632 total time= 9.2min
# [CV 2/5] END C=1, class_weight=balanced, decision_function_shape=ovr, gamma=0.0001, kernel=rbf;, score=-0.629 total time= 9.2min
# [CV 3/5] END C=1, class_weight=balanced, decision_function_shape=ovr, gamma=0.0001, kernel=rbf;, score=-0.610 total time= 9.0min
# [CV 5/5] END C=1, class_weight=balanced, decision_function_shape=ovr, gamma=0.0001, kernel=rbf;, score=-0.625 total time= 8.8min
# [CV 4/5] END C=1, class_weight=balanced, decision_function_shape=ovr, gamma=0.0001, kernel=rbf;, score=-0.609 total time= 9.0min
# [CV 1/5] END C=10, class_weight=balanced, decision_function_shape=ovr, gamma=1, kernel=rbf;, score=-0.994 total time=18.8min
# [CV 2/5] END C=10, class_weight=balanced, decision_function_shape=ovr, gamma=1, kernel=rbf;, score=-0.990 total time=19.4min
# [CV 5/5] END C=10, class_weight=balanced, decision_function_shape=ovr, gamma=1, kernel=rbf;, score=-0.991 total time=16.9min
# [CV 4/5] END C=10, class_weight=balanced, decision_function_shape=ovr, gamma=1, kernel=rbf;, score=-0.994 total time=19.3min
# [CV 3/5] END C=10, class_weight=balanced, decision_function_shape=ovr, gamma=1, kernel=rbf;, score=-0.994 total time=20.7min
# [CV 1/5] END C=10, class_weight=balanced, decision_function_shape=ovr, gamma=0.1, kernel=rbf;, score=-0.991 total time=18.5min
# [CV 2/5] END C=10, class_weight=balanced, decision_function_shape=ovr, gamma=0.1, kernel=rbf;, score=-0.989 total time=18.6min
# [CV 3/5] END C=10, class_weight=balanced, decision_function_shape=ovr, gamma=0.1, kernel=rbf;, score=-0.991 total time=21.2min
# [CV 5/5] END C=10, class_weight=balanced, decision_function_shape=ovr, gamma=0.1, kernel=rbf;, score=-0.991 total time=17.9min
# [CV 4/5] END C=10, class_weight=balanced, decision_function_shape=ovr, gamma=0.1, kernel=rbf;, score=-0.992 total time=19.9min
# [CV 1/5] END C=10, class_weight=balanced, decision_function_shape=ovr, gamma=0.01, kernel=rbf;, score=-0.934 total time=18.6min
# [CV 2/5] END C=10, class_weight=balanced, decision_function_shape=ovr, gamma=0.01, kernel=rbf;, score=-0.944 total time=17.3min
# [CV 4/5] END C=10, class_weight=balanced, decision_function_shape=ovr, gamma=0.01, kernel=rbf;, score=-0.949 total time=17.5min
# [CV 3/5] END C=10, class_weight=balanced, decision_function_shape=ovr, gamma=0.01, kernel=rbf;, score=-0.947 total time=19.4min
# [CV 5/5] END C=10, class_weight=balanced, decision_function_shape=ovr, gamma=0.01, kernel=rbf;, score=-0.960 total time=18.5min
# [CV 1/5] END C=10, class_weight=balanced, decision_function_shape=ovr, gamma=0.001, kernel=rbf;, score=-0.657 total time=28.4min
# [CV 2/5] END C=10, class_weight=balanced, decision_function_shape=ovr, gamma=0.001, kernel=rbf;, score=-0.672 total time=28.4min
# [CV 3/5] END C=10, class_weight=balanced, decision_function_shape=ovr, gamma=0.001, kernel=rbf;, score=-0.652 total time=28.7min
# [CV 1/5] END C=10, class_weight=balanced, decision_function_shape=ovr, gamma=0.0001, kernel=rbf;, score=-0.654 total time= 9.1min
# [CV 2/5] END C=10, class_weight=balanced, decision_function_shape=ovr, gamma=0.0001, kernel=rbf;, score=-0.650 total time= 9.0min
# [CV 5/5] END C=10, class_weight=balanced, decision_function_shape=ovr, gamma=0.001, kernel=rbf;, score=-0.661 total time=28.5min
# [CV 4/5] END C=10, class_weight=balanced, decision_function_shape=ovr, gamma=0.001, kernel=rbf;, score=-0.650 total time=28.7min
# [CV 3/5] END C=10, class_weight=balanced, decision_function_shape=ovr, gamma=0.0001, kernel=rbf;, score=-0.627 total time= 9.1min
# [CV 4/5] END C=10, class_weight=balanced, decision_function_shape=ovr, gamma=0.0001, kernel=rbf;, score=-0.633 total time= 9.2min
# [CV 5/5] END C=10, class_weight=balanced, decision_function_shape=ovr, gamma=0.0001, kernel=rbf;, score=-0.648 total time= 8.9min
# [CV 1/5] END C=100, class_weight=balanced, decision_function_shape=ovr, gamma=1, kernel=rbf;, score=-0.994 total time=18.4min
# [CV 2/5] END C=100, class_weight=balanced, decision_function_shape=ovr, gamma=1, kernel=rbf;, score=-0.990 total time=20.2min
# [CV 5/5] END C=100, class_weight=balanced, decision_function_shape=ovr, gamma=1, kernel=rbf;, score=-0.991 total time=16.8min
# [CV 4/5] END C=100, class_weight=balanced, decision_function_shape=ovr, gamma=1, kernel=rbf;, score=-0.994 total time=20.0min
# [CV 3/5] END C=100, class_weight=balanced, decision_function_shape=ovr, gamma=1, kernel=rbf;, score=-0.994 total time=20.8min
# [CV 1/5] END C=100, class_weight=balanced, decision_function_shape=ovr, gamma=0.1, kernel=rbf;, score=-0.991 total time=17.3min
# [CV 2/5] END C=100, class_weight=balanced, decision_function_shape=ovr, gamma=0.1, kernel=rbf;, score=-0.988 total time=17.3min
# [CV 3/5] END C=100, class_weight=balanced, decision_function_shape=ovr, gamma=0.1, kernel=rbf;, score=-0.991 total time=19.7min
# [CV 5/5] END C=100, class_weight=balanced, decision_function_shape=ovr, gamma=0.1, kernel=rbf;, score=-0.991 total time=16.6min
# [CV 4/5] END C=100, class_weight=balanced, decision_function_shape=ovr, gamma=0.1, kernel=rbf;, score=-0.992 total time=19.6min
# [CV 1/5] END C=100, class_weight=balanced, decision_function_shape=ovr, gamma=0.01, kernel=rbf;, score=-0.929 total time=17.9min
# [CV 2/5] END C=100, class_weight=balanced, decision_function_shape=ovr, gamma=0.01, kernel=rbf;, score=-0.951 total time=18.0min
# [CV 4/5] END C=100, class_weight=balanced, decision_function_shape=ovr, gamma=0.01, kernel=rbf;, score=-0.954 total time=19.2min
# [CV 5/5] END C=100, class_weight=balanced, decision_function_shape=ovr, gamma=0.01, kernel=rbf;, score=-0.956 total time=17.5min
# [CV 3/5] END C=100, class_weight=balanced, decision_function_shape=ovr, gamma=0.01, kernel=rbf;, score=-0.946 total time=20.3min
# [CV 1/5] END C=100, class_weight=balanced, decision_function_shape=ovr, gamma=0.001, kernel=rbf;, score=-0.659 total time=28.7min
# [CV 2/5] END C=100, class_weight=balanced, decision_function_shape=ovr, gamma=0.001, kernel=rbf;, score=-0.670 total time=29.9min
# [CV 3/5] END C=100, class_weight=balanced, decision_function_shape=ovr, gamma=0.001, kernel=rbf;, score=-0.653 total time=34.8min
# [CV 4/5] END C=100, class_weight=balanced, decision_function_shape=ovr, gamma=0.001, kernel=rbf;, score=-0.646 total time=34.9min
# [CV 5/5] END C=100, class_weight=balanced, decision_function_shape=ovr, gamma=0.001, kernel=rbf;, score=-0.669 total time=35.0min
# [CV 1/5] END C=100, class_weight=balanced, decision_function_shape=ovr, gamma=0.0001, kernel=rbf;, score=-0.668 total time=104.3min
# [CV 2/5] END C=100, class_weight=balanced, decision_function_shape=ovr, gamma=0.0001, kernel=rbf;, score=-0.660 total time=103.3min
# [CV 5/5] END C=100, class_weight=balanced, decision_function_shape=ovr, gamma=0.0001, kernel=rbf;, score=-0.668 total time=97.9min
# [CV 3/5] END C=100, class_weight=balanced, decision_function_shape=ovr, gamma=0.0001, kernel=rbf;, score=-0.648 total time=99.9min
# [CV 4/5] END C=100, class_weight=balanced, decision_function_shape=ovr, gamma=0.0001, kernel=rbf;, score=-0.660 total time=100.5min
# [CV 1/5] END C=1000, class_weight=balanced, decision_function_shape=ovr, gamma=1, kernel=rbf;, score=-0.994 total time=17.6min
# [CV 2/5] END C=1000, class_weight=balanced, decision_function_shape=ovr, gamma=1, kernel=rbf;, score=-0.990 total time=17.6min
# [CV 5/5] END C=1000, class_weight=balanced, decision_function_shape=ovr, gamma=1, kernel=rbf;, score=-0.992 total time=17.1min
# [CV 3/5] END C=1000, class_weight=balanced, decision_function_shape=ovr, gamma=1, kernel=rbf;, score=-0.993 total time=19.5min
# [CV 4/5] END C=1000, class_weight=balanced, decision_function_shape=ovr, gamma=1, kernel=rbf;, score=-0.994 total time=19.2min
# [CV 1/5] END C=1000, class_weight=balanced, decision_function_shape=ovr, gamma=0.1, kernel=rbf;, score=-0.991 total time=17.5min
# [CV 2/5] END C=1000, class_weight=balanced, decision_function_shape=ovr, gamma=0.1, kernel=rbf;, score=-0.989 total time=21.8min
# [CV 5/5] END C=1000, class_weight=balanced, decision_function_shape=ovr, gamma=0.1, kernel=rbf;, score=-0.991 total time=15.9min
# [CV 4/5] END C=1000, class_weight=balanced, decision_function_shape=ovr, gamma=0.1, kernel=rbf;, score=-0.990 total time=17.6min
# [CV 3/5] END C=1000, class_weight=balanced, decision_function_shape=ovr, gamma=0.1, kernel=rbf;, score=-0.991 total time=21.1min
# [CV 1/5] END C=1000, class_weight=balanced, decision_function_shape=ovr, gamma=0.01, kernel=rbf;, score=-0.922 total time=18.7min
# [CV 2/5] END C=1000, class_weight=balanced, decision_function_shape=ovr, gamma=0.01, kernel=rbf;, score=-0.921 total time=17.3min
# [CV 4/5] END C=1000, class_weight=balanced, decision_function_shape=ovr, gamma=0.01, kernel=rbf;, score=-0.947 total time=17.9min
# [CV 3/5] END C=1000, class_weight=balanced, decision_function_shape=ovr, gamma=0.01, kernel=rbf;, score=-0.947 total time=20.1min
# [CV 5/5] END C=1000, class_weight=balanced, decision_function_shape=ovr, gamma=0.01, kernel=rbf;, score=-0.947 total time=16.7min
# [CV 1/5] END C=1000, class_weight=balanced, decision_function_shape=ovr, gamma=0.001, kernel=rbf;, score=-0.666 total time=28.2min
# [CV 2/5] END C=1000, class_weight=balanced, decision_function_shape=ovr, gamma=0.001, kernel=rbf;, score=-0.664 total time=28.5min
# [CV 3/5] END C=1000, class_weight=balanced, decision_function_shape=ovr, gamma=0.001, kernel=rbf;, score=-0.656 total time=28.6min
# [CV 4/5] END C=1000, class_weight=balanced, decision_function_shape=ovr, gamma=0.001, kernel=rbf;, score=-0.649 total time=28.9min
# [CV 5/5] END C=1000, class_weight=balanced, decision_function_shape=ovr, gamma=0.001, kernel=rbf;, score=-0.669 total time=29.3min
# [CV 1/5] END C=1000, class_weight=balanced, decision_function_shape=ovr, gamma=0.0001, kernel=rbf;, score=-0.680 total time=125.8min
# [CV 2/5] END C=1000, class_weight=balanced, decision_function_shape=ovr, gamma=0.0001, kernel=rbf;, score=-0.674 total time=125.1min
# [CV 3/5] END C=1000, class_weight=balanced, decision_function_shape=ovr, gamma=0.0001, kernel=rbf;, score=-0.670 total time=125.0min
# [CV 5/5] END C=1000, class_weight=balanced, decision_function_shape=ovr, gamma=0.0001, kernel=rbf;, score=-0.689 total time=122.4min
# [CV 4/5] END C=1000, class_weight=balanced, decision_function_shape=ovr, gamma=0.0001, kernel=rbf;, score=-0.669 total time=124.7min
# Best Parameters: {'C': 1, 'class_weight': 'balanced', 'decision_function_shape': 'ovr', 'gamma': 0.0001, 'kernel': 'rbf'}
# Best score found:  0.6210809582214318
# Best estimator: SVC(C=1, class_weight='balanced', gamma=0.0001, random_state=42)
# Execution time: 10 hours, 46 minutes, 18 seconds

# %% [raw]
# Best Parameters: {'C': 1, 'class_weight': 'balanced', 'decision_function_shape': 'ovr', 'gamma': 0.0001, 'kernel': 'rbf'}
# Best score found:  0.6210809582214318
# Best estimator: SVC(C=1, class_weight='balanced', gamma=0.0001, random_state=42)
# Execution time: 10 hours, 46 minutes, 18 seconds

# %%
# Save Gridsearch and 5CV results 
SVC_nofeat_CV = pd.DataFrame(svm_random.cv_results_)
SVC_nofeat_CV.to_csv('SVC_nofeat_CV.csv', index=False)
box_fig = pd.read_csv('SVC_nofeat_CV.csv')

# %%
plt.figure(figsize=(10, 6))
for i in range(test_scores_flipped.shape[0]):
    plt.plot(C_values, test_scores_flipped[i], marker='o', linestyle='-', label=f'Fold {i+1}')

plt.xlabel('C')
plt.ylabel('MAE Score (Positive)')
plt.title('MAE Score vs. C')
plt.legend()
plt.grid(True)
plt.ylim(0.5, 1.1)
plt.tight_layout()
plt.savefig('MAE_vsC.png', dpi=300, bbox_inches='tight')  # Save as PNG
plt.show()

# %%
# Plot MAE scores average per cross validation
cv_scores = -box_fig['mean_test_score']
plt.plot(range(1, len(cv_scores) + 1), cv_scores, '-o', label='Average MAE across folds per iteration', color='#1f77b4')

plt.xlabel('Numbers of iterations', fontsize=14, labelpad=10)
plt.ylabel('MAE', fontsize=14, labelpad=10)
plt.title('SVC 5-Fold Cross Validation MAE per Iteration', fontsize=16, pad=20)
plt.grid(True, linestyle='--', linewidth=0.5, alpha=0.5)
plt.tick_params(axis='both', which='major', labelsize=12)
plt.ylim(0.5, 1.1)
plt.legend(fontsize=12)
plt.tight_layout()
plt.savefig('SVC_avg_mae_iteration', dpi=300, bbox_inches='tight')  # Save as PNG
plt.show()

# %%
# Trained SVC predict test data with best estimator
svm_random1 = svm_random.best_estimator_
y_pred = svm_random1.predict(X_test)

# %%
# Evaluation
svc_mae = mean_absolute_error(y_test, y_pred)
print(f'Test MAE: {svc_mae:.3f}')
svc_mse = mean_squared_error(y_test, y_pred)
svc_rmse = svc_mse ** 0.5
print(f'Test RMSE: {svc_rmse:.3f}')
svc_kappa = cohen_kappa_score(y_test, y_pred, weights='quadratic')
print(f'Test CWK: {svc_kappa:.3f}')

# Confusion matrix
class_labels = {1: 'challenging', 2: 'moderate', 3: 'user-friendly'}
conf_matrix = confusion_matrix(y_test, y_pred)
conf_matrix_percent = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]
plt.figure(figsize=(8, 6))
plt.imshow(conf_matrix_percent, cmap=plt.cm.Blues, vmin=0, vmax=1)
plt.title('Confusion Matrix SVC')
plt.colorbar(label='Percentage')
for i in range(conf_matrix.shape[0]):
    for j in range(conf_matrix.shape[1]):
        plt.text(j, i, f'{conf_matrix_percent[i, j]:.2f}', ha='center', va='center', color='black')
plt.xlabel('Predicted class')
plt.ylabel('True class')
plt.xticks(np.arange(len(class_labels)), [class_labels[i] for i in sorted(class_labels)], rotation=45)
plt.yticks(np.arange(len(class_labels)), [class_labels[i] for i in sorted(class_labels)])
plt.tight_layout()
plt.savefig('SVC_confusionmatrixTB', dpi=300, bbox_inches='tight')  # Save as PNG
plt.show()
# Out:
# Test MAE: 0.621
# Test RMSE: 0.958
# Test CWK: 0.326
